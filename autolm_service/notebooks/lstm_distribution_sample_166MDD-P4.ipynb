# %%
import numpy as np
import pandas as pd

def distribuir_votos_por_hora(total_votos=166470734, minutos_por_grupo=10, seed=42, suavidad=5):
    """
    Distribuye votos de una jornada electoral en grupos de tiempo.

    Implementa distribución por hora usando porcentajes de Caltech (2015),
    luego distribuye suavemente cada hora entre sus grupos de tiempo 
    usando Dirichlet no-homogéneo.

    Parámetros:
    -----------
    total_votos : int
        Número total de votos a distribuir (default: 166,470,734)
    minutos_por_grupo : int
        Minutos que representa cada grupo: 10, 5, o 1 (default: 10)
    seed : int
        Semilla para reproducibilidad (default: 42)
    suavidad : int
        Parámetro de concentración Dirichlet (mayor = más uniforme, default: 5)

    Retorna:
    --------
    pd.DataFrame con columnas:
        - voting_hour_12: índice del grupo (0 a num_grupos-1)
        - total_votos: cantidad de votos en ese grupo
    """

    # Establecer semilla para reproducibilidad en experimentos
    np.random.seed(seed)

    # Porcentajes de Caltech 2015 por hora (7 AM a 7 PM, 12 horas totales)
    percentages_caltech = np.array([12.57, 7.01, 7.65, 5.48, 7.01, 4.35, 5.80, 5.40, 5.07, 5.40, 4.26, 30.00])

    # Normalizar porcentajes para garantizar suma exacta de 100%
    percentages_caltech = percentages_caltech / percentages_caltech.sum() * 100

    # Obtener número de horas en la jornada electoral
    num_horas = len(percentages_caltech)

    # Calcular cantidad de votos por hora basado en porcentajes de Caltech
    votos_por_hora = (percentages_caltech / 100) * total_votos
    votos_por_hora = votos_por_hora.astype(int)

    # Ajustar primer hora para asegurar que suma total sea exacta
    votos_por_hora[0] += total_votos - votos_por_hora.sum()

    # Calcular número total de grupos y grupos por cada hora
    minutos_jornada = num_horas * 60
    num_grupos_total = int(minutos_jornada // minutos_por_grupo)
    grupos_por_hora = int(60 // minutos_por_grupo)

    # Inicializar array para almacenar distribución de votos por grupo
    votos_grupo = np.zeros(num_grupos_total, dtype=int)

    # Iterar sobre cada hora para distribuir sus votos en sus grupos
    for hora in range(num_horas):
        # Calcular índices de inicio y fin para grupos de esta hora
        inicio = hora * grupos_por_hora
        fin = inicio + grupos_por_hora

        # Generar proporciones aleatorias suaves con distribución Dirichlet
        # Dirichlet proporciona un patrón no-homogéneo sin variaciones bruscas
        parametro_dirichlet = np.ones(grupos_por_hora) * suavidad
        proporciones = np.random.dirichlet(parametro_dirichlet)

        # Distribuir votos de esta hora entre sus grupos usando proporciones
        votos_distribuidos = (proporciones * votos_por_hora[hora]).astype(int)

        # Ajustar primer grupo de hora para mantener exactitud en suma
        diferencia = votos_por_hora[hora] - votos_distribuidos.sum()
        votos_distribuidos[0] += diferencia

        # Asignar votos distribuidos a los grupos de esta hora
        votos_grupo[inicio:fin] = votos_distribuidos

    # Crear DataFrame con estructura requerida para LSTM
    df = pd.DataFrame({
        'voting_hour_12': np.arange(num_grupos_total),
        'total_votos': votos_grupo
    })

    return df


# EJEMPLO 1: Distribución con grupos de 10 minutos (72 grupos)
#df_10min = distribuir_votos_por_hora(minutos_por_grupo=10, seed=42)
#print("Distribución con 10 minutos por grupo:")
#print(f"- Número de grupos: {len(df_10min)}")
#print(f"- Total de votos: {df_10min['total_votos'].sum():,}")
#print(f"\nPrimeras 6 filas (primera hora):\n{df_10min.head(10)}")

## EJEMPLO 2: Distribución con grupos de 5 minutos (144 grupos)
#df_5min = distribuir_votos_por_hora(minutos_por_grupo=5, seed=42)
#print(f"\nDistribución con 5 minutos por grupo:")
#print(f"- Número de grupos: {len(df_5min)}")

## EJEMPLO 3: Distribución con grupos de 1 minuto (720 grupos)
#df_1min = distribuir_votos_por_hora(minutos_por_grupo=1, seed=42)
#print(f"\nDistribución con 1 minuto por grupo:")
#print(f"- Número de grupos: {len(df_1min)}")

# EJEMPLO 4: Cambiar parámetro de suavidad para variar aleatoridad
#df_suave = distribuir_votos_por_hora(minutos_por_grupo=5, suavidad=25, seed=42)
#print(f"\nDistribución con suavidad=20 (más uniforme):")
#print(f"Desviación estándar de votos: {df_suave['total_votos'].std():,.0f}")

#df_brusco = distribuir_votos_por_hora(minutos_por_grupo=10, suavidad=1, seed=42)
#print(f"\nDistribución con suavidad=1 (más variable):")
#print(f"Desviación estándar de votos: {df_brusco['total_votos'].std():,.0f}")

# %%
# EJEMPLO 1: Distribución con grupos de 10 minutos (72 grupos)
df_prueba = distribuir_votos_por_hora(minutos_por_grupo=5, suavidad=30, seed=42)
print("Distribución con 5 minutos por grupo:")
print(f"- Número de grupos: {len(df_prueba)}")
#print(f"- Total de votos: {df_5_suave['total_votos'].sum():,}")
print(f"\nPrimeras 12 filas (primera hora):\n{df_prueba.head(12)}")
# Out:
# Distribución con 5 minutos por grupo:
# - Número de grupos: 144
#
# Primeras 12 filas (primera hora):
#     voting_hour_12  total_votos
# 0                0      1893925
# 1                1      1687617
# 2                2      1657830
# 3                3      1657835
# 4                4      2283206
# 5                5      1986751
# 6                6      1586220
# 7                7      1909430
# 8                8      1809243
# 9                9      1191498
# 10              10      1428814
# 11              11      1833007

# %%
import matplotlib.pyplot as plt
import numpy as np

# Correr la serie
df = distribuir_votos_por_hora(minutos_por_grupo=5, suavidad=30, seed=42)

# Extraer datos del DataFrame (tu df se llama 'df')
groups = df['voting_hour_12'].values   # Grupos de 0 a 71
series = df['total_votos'].values      # Cantidad de votos por grupo

# Crear figura más grande para 72 puntos
plt.figure(figsize=(18, 7))

# Plotear la serie de tiempo
plt.plot(groups, series, marker='o', linewidth=1.5, markersize=4, 
         color='#2E86AB', label='Votos por Grupo de 5 min en 12 hrs')

# Personalización
plt.xlabel('Grupo de 5 Minutos (0-143)', fontsize=12, fontweight='bold')
plt.ylabel('Total de Votos', fontsize=12, fontweight='bold')
plt.title('Distribución Temporal de 166,470,734 Votos por Grupos de 5 Minutos\n(Hora 5:00 AM - 4:59 PM)', 
          fontsize=14, fontweight='bold')

# Configurar el eje X para mostrar cada grupo
plt.xticks(range(0, 144, 12), fontsize=9)  # Mostrar cada 6 grupos (cada hora)
plt.grid(True, alpha=0.3, linestyle='--')
plt.legend(fontsize=11, loc='upper left')

# Agregar líneas verticales cada hora (cada 12 grupos)
for h in range(0, 144, 12):
    plt.axvline(x=h, color='gray', linestyle=':', alpha=0.5, linewidth=0.8)

# Agregar etiquetas de hora en el eje X secundario
ax = plt.gca()
ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim())
hora_labels = [f'{5+i}:00' for i in range(12)]  # De 5:00 AM a 16:00 (4 PM)
ax2.set_xticks(range(0, 144, 12))
ax2.set_xticklabels(hora_labels, fontsize=9)
ax2.set_xlabel('Hora del Día', fontsize=11, fontweight='bold')

# Mostrar valores solo en puntos clave (cada 12 grupos)
for i in range(0, len(groups), 6):
    plt.text(groups[i], series[i] + max(series)*0.02, 
             f'{int(series[i]):,}', ha='center', fontsize=8, rotation=45)

plt.tight_layout()
plt.show()

print(f"\nEstadísticas del gráfico:")
print(f"  - Total de grupos: {len(groups)}")
print(f"  - Rango de grupos: {groups.min()} a {groups.max()}")
print(f"  - Total de votos: {series.sum():,}")
# Out:
# Estadísticas del gráfico:
#   - Total de grupos: 144
#   - Rango de grupos: 0 a 143
#   - Total de votos: 166,470,734

# %%
df
# Out:
#      voting_hour_12  total_votos
# 0                 0      1893925
# 1                 1      1687617
# 2                 2      1657830
# 3                 3      1657835
# 4                 4      2283206
# ..              ...          ...
# 139             139      4807525
# 140             140      4290016
# 141             141      3765395
# 142             142      2860465
# 143             143      4401625
#
# [144 rows x 2 columns]

# %%
# Índice para el 80%
index_80 = int(len(series) * 0.6)
# Índice para el 90% (80% + 10%) y el 10% restante
index_90 = int(len(series) * 0.75)

# Partimos la serie en función de las proporciones
train = series[:index_80]               #Entrenamiento
valid = series[index_80:index_90]             #Validación
test  = series[index_90:]              #Prueba 

#Ahora hacemos el proceso de normalización, esto poniendo los datos dentro de una escala entre 0 y 1
# 1) Tomamos la “escala” como el valor máximo observado en TRAIN
scale = float(train.max()) if float(train.max()) != 0 else 1.0

# 2) Divides cada serie por la escala → todo queda en ~[0, 1]
y_train = (train / scale).astype('float32')
y_valid = (valid / scale).astype('float32')
y_test  = (test  / scale).astype('float32')

print("Grupos definidos")
print("[Entrenamiento, validación y prueba]")
grupos = [y_train, y_valid, y_test]
grupos
# Out:
# Grupos definidos
# [Entrenamiento, validación y prueba]
# [array([0.82950246, 0.73914355, 0.7260974 , 0.7260996 , 1.        ,
#         0.87015843, 0.6947336 , 0.83629334, 0.7924134 , 0.521853  ,
#         0.62579286, 0.8028216 , 0.57029283, 0.42271876, 0.39813754,
#         0.4497737 , 0.3938992 , 0.41755232, 0.43964538, 0.36056975,
#         0.5107021 , 0.34914544, 0.34176198, 0.4568589 , 0.5056749 ,
#         0.45695308, 0.43353558, 0.41883823, 0.40646398, 0.53450805,
#         0.46975   , 0.4122935 , 0.39008087, 0.49449328, 0.53210396,
#         0.5229927 , 0.27661717, 0.30596977, 0.29634076, 0.3130988 ,
#         0.37479842, 0.41158178, 0.3460117 , 0.28713617, 0.3218921 ,
#         0.42629486, 0.32922435, 0.30655447, 0.40345857, 0.44833055,
#         0.36084086, 0.38264483, 0.4948222 , 0.44605   , 0.42770866,
#         0.49941662, 0.3683106 , 0.3954019 , 0.44343567, 0.4406374 ,
#         0.20128451, 0.24427012, 0.25640482, 0.2842332 , 0.27683792,
#         0.26055557, 0.18159421, 0.2628659 , 0.26708147, 0.40252304,
#         0.25493014, 0.27904534, 0.43694392, 0.4082838 , 0.45672488,
#         0.27257156, 0.29571226, 0.3209154 , 0.26450658, 0.36124423,
#         0.29984155, 0.46818203, 0.30785483, 0.3360542 , 0.3821022 ,
#         0.2611179 ], dtype=float32),
#  array([0.24207452, 0.34159598, 0.3462837 , 0.37998542, 0.36294404,
#         0.34861112, 0.29073066, 0.3445576 , 0.34836498, 0.28882325,
#         0.39672154, 0.312504  , 0.23849578, 0.33029783, 0.34060222,
#         0.30911228, 0.27409264, 0.24893285, 0.28278044, 0.3051643 ,
#         0.2875067 , 0.37037483], dtype=float32),
#  array([0.38397938, 0.29184008, 0.27991998, 0.37433636, 0.32916084,
#         0.39000556, 0.3737201 , 0.3384767 , 0.29242653, 0.2562073 ,
#         0.35670456, 0.27041405, 0.19331764, 0.23491879, 0.2308609 ,
#         0.18375434, 0.27690667, 0.27551433, 0.2506975 , 0.25064185,
#         0.2506979 , 0.43106666, 0.27079904, 0.25683096, 1.6112384 ,
#         1.7834637 , 2.7726154 , 1.294739  , 1.7064811 , 2.261216  ,
#         1.6291618 , 2.1056027 , 1.8789439 , 1.64917   , 1.2528282 ,
#         1.9278265 ], dtype=float32)]

# %%
import tensorflow as tf
tf.random.set_seed(42)

# tamaño de la secuencia optima.
seq_length = 13
#max(2, min(56, len(y_train) - 1, len(y_valid) - 1, len(y_test) - 1))
print(seq_length)
batch_size = 16

# Función para calcular las ventanas deslizantes, la ventana maxima viable
def make_ds(series_1d, seq_len, batch=16, shuffle_input=False, seed=42):
    return tf.keras.utils.timeseries_dataset_from_array(
        data=series_1d,                # serie, ya normalizada.
        targets=series_1d[seq_len:],   # targets=series_1d[seq_len:]: define que el modelo aprende a predecir el siguiente punto a partir de la ventana de tamaño seq_len.
        sequence_length=seq_len,       # el tamaño de la ventana que tendra la mini serie de tiempo  
        batch_size=batch,              # se divide el anterior dato en 32 aleatoriamente con la semilla
        shuffle=shuffle_input,         # si se revuelve o no los datos, si es aleatoria esta batch de 32 a partir de los targets
        seed=seed                      # para asegurar reproducibilidad
    )

train_ds = make_ds(y_train, seq_length, batch_size, shuffle_input=True,  seed=42)  #se combinan para que aprenda de diferentes puntos la red
valid_ds = make_ds(y_valid, seq_length, batch_size, shuffle_input=False)           #no se combinan porque solo se predice directamente para obtener el valor de la metrica
test_ds  = make_ds(y_test,  seq_length, batch_size, shuffle_input=False)           #igual que arriba

print("seq_length usado:", seq_length)
print(train_ds)
# Out:
# 13
# seq_length usado: 13
# <_BatchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
def fit_and_evaluate(model, train_set, valid_set, learning_rate, epochs=300):
    """
    Entrena un modelo recurrente para predecir t+1.
    
    Argumentos:
        model: Modelo LSTM/RNN de Keras
        train_set: Dataset de entrenamiento (ventanas deslizantes)
        valid_set: Dataset de validación
        learning_rate: Tasa de aprendizaje para SGD
        epochs: Número máximo de épocas (iteraciones completas sobre los datos)
    
    Retorna:
        history: Historial de entrenamiento (pérdidas, métricas)
        val_mae: MAE en validación (en unidades originales, no normalizadas)
    """
    
    # Early Stopping: Detiene entrenamiento si no mejora en 50 épocas
            # Previene sobre ajuste
    cb = tf.keras.callbacks.EarlyStopping(
        monitor="val_mae",           # Métrica a monitorear
        patience=50,                 # Épocas sin mejora antes de detener
        restore_best_weights=True    # Restaura pesos de la mejor época
    )
    
    # Optimizador Stochastic Gradient Descent (SGD) con momentum
    opt = tf.keras.optimizers.SGD(
        learning_rate=learning_rate,  # Tamaño del paso en la dirección del gradiente, muy alto modelo diverge, muy bajo convergencia lenta
        momentum=0.9                  # Inercia (acelera convergencia, típicamente entre 0.9-0.99), Acelera convergencia y ayuda a escapar de mínimos locales poco profundos
    )
    
    # Compilación del modelo
    model.compile(
        loss=tf.keras.losses.Huber(),  # Función híbrida que combina MSE (errores pequeños) y MAE (errores grandes), más robusta (para la compilación)
        optimizer=opt,                 # Algoritmo de optimización
        metrics=["mae"]                # Métricas adicionales a reportar   (la que se usa para compara con otros modelos)
    )
    
    # Entrenamiento
    history = model.fit(
        train_set,                    # Datos de entrenamiento
        validation_data=valid_set,    # Datos de validación
        epochs=epochs,                # Épocas máximas
        callbacks=[cb],               # Lista de callbacks
        verbose=1                     # Mostrar progreso, imprimir la salida (imprimir más)
    )
    
    # Evaluación final en validación
    _, val_mae = model.evaluate(valid_set, verbose=0)
    
    # Desnormalizar MAE
    return history, float(val_mae) * scale   # reescala a votos/hora, multimplicamos por la escala hecha anteriormente

print("Función fit_and_evaluate() definida")
# Out:
# Función fit_and_evaluate() definida

# %% [markdown]
# ### Ejemplo de Salida del siguiente código, es necesario describir que está pasando
#
# - Epoch 100/300
# - 45/45 [==============================] - 0s 3ms/step - loss: 0.0045 - mae: 0.0045 - val_loss: 0.0042 - val_mae: 0.0042
# - Epoch 150/300
#
# ¿Qué significa cada cosa?
# - loss (perdida)  :Huber loss en el entrenamiento (dato normalizado)
# - mae             :Error Medio absoluto (Normalizado)
# - val_loss:       :Huber loss en validación
# - val_mae:        :MAE en validación (encargado de monitorear Early Stopping)

# %%
tf.random.set_seed(42)

model_lstm = tf.keras.Sequential([
    tf.keras.layers.LSTM(
        16,                              #Dimension de las capas ocultas, entre más, también más riesgo de overfitting
        input_shape=[None, 1]),          #NONE es aceptar secuencias de cualquier longitud, el tamño de la ventana #1 es el no de caracteristicas por paso, y solo analizamos los votos
    tf.keras.layers.Dense(1)             #Solo se predice un dato de salida, la cantidad de votos en t+1 (la estructura es una unica salida y una sola capa densa)
])

hist_lstm, valid_mae_lstm = fit_and_evaluate(model_lstm, train_ds, test_ds, learning_rate=0.05, epochs=500)

print(f"Valid MAE sin normalizar (LSTM-32): {valid_mae_lstm/scale}")
print(f"Valid MAE (LSTM-32): {valid_mae_lstm:,.0f} votos/5min")
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0644 - val_loss: 0.2829 - val_mae: 0.5552
# Epoch 135/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0642 - val_loss: 0.2879 - val_mae: 0.5575
# Epoch 136/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029 - mae: 0.0637 - val_loss: 0.2858 - val_mae: 0.5562
# Epoch 137/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0640 - val_loss: 0.2838 - val_mae: 0.5550
# Epoch 138/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0648 - val_loss: 0.2885 - val_mae: 0.5569
# Epoch 139/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0634 - val_loss: 0.2832 - val_mae: 0.5540
# Epoch 140/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0646 - val_loss: 0.2801 - val_mae: 0.5523
# Epoch 141/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0643 - val_loss: 0.2840 - val_mae: 0.5537
# Epoch 142/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0030 - mae: 0.0650 - val_loss: 0.2886 - val_mae: 0.5558
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028 - mae: 0.0630 - val_loss: 0.2791 - val_mae: 0.5510
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0029 - mae: 0.0648 - val_loss: 0.2787 - val_mae: 0.5506
# Epoch 145/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0642 - val_loss: 0.2876 - val_mae: 0.5549
# Epoch 146/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0029 - mae: 0.0636 - val_loss: 0.2862 - val_mae: 0.5544
# Epoch 147/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0028 - mae: 0.0633 - val_loss: 0.2804 - val_mae: 0.5517
# Epoch 148/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0646 - val_loss: 0.2803 - val_mae: 0.5516
# Epoch 149/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0030 - mae: 0.0651 - val_loss: 0.2887 - val_mae: 0.5553
# Epoch 150/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0633 - val_loss: 0.2824 - val_mae: 0.5523
# Epoch 151/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0029 - mae: 0.0651 - val_loss: 0.2763 - val_mae: 0.5494
# Epoch 152/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0641 - val_loss: 0.2863 - val_mae: 0.5537
# Epoch 153/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0633 - val_loss: 0.2881 - val_mae: 0.5545
# Epoch 154/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0640 - val_loss: 0.2786 - val_mae: 0.5501
# Epoch 155/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0029 - mae: 0.0641 - val_loss: 0.2817 - val_mae: 0.5515
# Epoch 156/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0029 - mae: 0.0637 - val_loss: 0.2865 - val_mae: 0.5535
# Epoch 157/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - mae: 0.0635 - val_loss: 0.2825 - val_mae: 0.5516
# Epoch 158/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0028 - mae: 0.0635 - val_loss: 0.2775 - val_mae: 0.5493
# Epoch 159/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0639 - val_loss: 0.2827 - val_mae: 0.5515
# Epoch 160/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2879 - val_mae: 0.5536
# Epoch 161/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0029 - mae: 0.0640 - val_loss: 0.2827 - val_mae: 0.5511
# Epoch 162/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0639 - val_loss: 0.2800 - val_mae: 0.5499
# Epoch 163/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0028 - mae: 0.0637 - val_loss: 0.2835 - val_mae: 0.5514
# Epoch 164/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0641 - val_loss: 0.2823 - val_mae: 0.5506
# Epoch 165/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0030 - mae: 0.0640 - val_loss: 0.2863 - val_mae: 0.5524
# Epoch 166/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2757 - val_mae: 0.5471
# Epoch 167/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0030 - mae: 0.0651 - val_loss: 0.2762 - val_mae: 0.5473
# Epoch 168/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0636 - val_loss: 0.2871 - val_mae: 0.5524
# Epoch 169/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0032 - mae: 0.0646 - val_loss: 0.2867 - val_mae: 0.5520
# Epoch 170/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0646 - val_loss: 0.2703 - val_mae: 0.5442
# Epoch 171/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0666 - val_loss: 0.2806 - val_mae: 0.5490
# Epoch 172/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0641 - val_loss: 0.2825 - val_mae: 0.5498
# Epoch 173/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0636 - val_loss: 0.2759 - val_mae: 0.5466
# Epoch 174/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0643 - val_loss: 0.2794 - val_mae: 0.5482
# Epoch 175/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0637 - val_loss: 0.2771 - val_mae: 0.5467
# Epoch 176/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0028 - mae: 0.0636 - val_loss: 0.2805 - val_mae: 0.5481
# Epoch 177/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0029 - mae: 0.0636 - val_loss: 0.2808 - val_mae: 0.5481
# Epoch 178/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0029 - mae: 0.0642 - val_loss: 0.2761 - val_mae: 0.5459
# Epoch 179/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0029 - mae: 0.0644 - val_loss: 0.2807 - val_mae: 0.5478
# Epoch 180/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0029 - mae: 0.0639 - val_loss: 0.2763 - val_mae: 0.5456
# Epoch 181/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0029 - mae: 0.0647 - val_loss: 0.2827 - val_mae: 0.5485
# Epoch 182/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - mae: 0.0640 - val_loss: 0.2777 - val_mae: 0.5463
# Epoch 183/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0639 - val_loss: 0.2790 - val_mae: 0.5468
# Epoch 184/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029 - mae: 0.0639 - val_loss: 0.2852 - val_mae: 0.5496
# Epoch 185/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0029 - mae: 0.0627 - val_loss: 0.2776 - val_mae: 0.5459
# Epoch 186/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0029 - mae: 0.0643 - val_loss: 0.2723 - val_mae: 0.5431
# Epoch 187/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0643 - val_loss: 0.2790 - val_mae: 0.5461
# Epoch 188/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0632 - val_loss: 0.2813 - val_mae: 0.5468
# Epoch 189/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0631 - val_loss: 0.2747 - val_mae: 0.5437
# Epoch 190/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0644 - val_loss: 0.2773 - val_mae: 0.5448
# Epoch 191/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0636 - val_loss: 0.2842 - val_mae: 0.5477
# Epoch 192/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2750 - val_mae: 0.5433
# Epoch 193/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0639 - val_loss: 0.2722 - val_mae: 0.5419
# Epoch 194/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0028 - mae: 0.0635 - val_loss: 0.2784 - val_mae: 0.5448
# Epoch 195/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0028 - mae: 0.0629 - val_loss: 0.2811 - val_mae: 0.5460
# Epoch 196/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2751 - val_mae: 0.5428
# Epoch 197/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0642 - val_loss: 0.2719 - val_mae: 0.5411
# Epoch 198/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0029 - mae: 0.0649 - val_loss: 0.2789 - val_mae: 0.5441
# Epoch 199/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028 - mae: 0.0635 - val_loss: 0.2746 - val_mae: 0.5419
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0030 - mae: 0.0651 - val_loss: 0.2741 - val_mae: 0.5416
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2729 - val_mae: 0.5373
# Epoch 236/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0028 - mae: 0.0632 - val_loss: 0.2726 - val_mae: 0.5370
# Epoch 237/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2711 - val_mae: 0.5361
# Epoch 238/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0632 - val_loss: 0.2736 - val_mae: 0.5371
# Epoch 239/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0630 - val_loss: 0.2705 - val_mae: 0.5356
# Epoch 240/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0639 - val_loss: 0.2688 - val_mae: 0.5347
# Epoch 241/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0633 - val_loss: 0.2722 - val_mae: 0.5361
# Epoch 242/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0028 - mae: 0.0630 - val_loss: 0.2716 - val_mae: 0.5357
# Epoch 243/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0029 - mae: 0.0634 - val_loss: 0.2680 - val_mae: 0.5335
# Epoch 244/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0635 - val_loss: 0.2710 - val_mae: 0.5347
# Epoch 245/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0030 - mae: 0.0643 - val_loss: 0.2751 - val_mae: 0.5363
# Epoch 246/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2649 - val_mae: 0.5312
# Epoch 247/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0639 - val_loss: 0.2665 - val_mae: 0.5319
# Epoch 248/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0030 - mae: 0.0641 - val_loss: 0.2749 - val_mae: 0.5356
# Epoch 249/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0622 - val_loss: 0.2656 - val_mae: 0.5311
# Epoch 250/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0653 - val_loss: 0.2626 - val_mae: 0.5297
# Epoch 251/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0636 - val_loss: 0.2744 - val_mae: 0.5354
# Epoch 252/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - mae: 0.0627 - val_loss: 0.2730 - val_mae: 0.5347
# Epoch 253/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2642 - val_mae: 0.5302
# Epoch 254/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0636 - val_loss: 0.2661 - val_mae: 0.5309
# Epoch 255/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0637 - val_loss: 0.2689 - val_mae: 0.5321
# Epoch 256/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0634 - val_loss: 0.2654 - val_mae: 0.5305
# Epoch 257/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0635 - val_loss: 0.2686 - val_mae: 0.5319
# Epoch 258/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2702 - val_mae: 0.5326
# Epoch 259/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2683 - val_mae: 0.5317
# Epoch 260/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0030 - mae: 0.0645 - val_loss: 0.2637 - val_mae: 0.5294
# Epoch 261/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0640 - val_loss: 0.2730 - val_mae: 0.5338
# Epoch 262/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0634 - val_loss: 0.2666 - val_mae: 0.5306
# Epoch 263/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2682 - val_mae: 0.5314
# Epoch 264/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0630 - val_loss: 0.2678 - val_mae: 0.5312
# Epoch 265/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0634 - val_loss: 0.2641 - val_mae: 0.5295
# Epoch 266/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2702 - val_mae: 0.5326
# Epoch 267/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0631 - val_loss: 0.2712 - val_mae: 0.5328
# Epoch 268/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.
500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2602 - val_mae: 0.5229
# Epoch 336/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0637 - val_loss: 0.2608 - val_mae: 0.5231
# Epoch 337/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2642 - val_mae: 0.5244
# Epoch 338/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0028 - mae: 0.0629 - val_loss: 0.2647 - val_mae: 0.5246
# Epoch 339/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2578 - val_mae: 0.5211
# Epoch 340/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0028 - mae: 0.0633 - val_loss: 0.2612 - val_mae: 0.5226
# Epoch 341/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2652 - val_mae: 0.5244
# Epoch 342/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0628 - val_loss: 0.2644 - val_mae: 0.5238
# Epoch 343/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0622 - val_loss: 0.2612 - val_mae: 0.5224
# Epoch 344/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0641 - val_loss: 0.2580 - val_mae: 0.5209
# Epoch 345/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0030 - mae: 0.0645 - val_loss: 0.2685 - val_mae: 0.5263
# Epoch 346/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0614 - val_loss: 0.2603 - val_mae: 0.5220
# Epoch 347/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0644 - val_loss: 0.2543 - val_mae: 0.5191
# Epoch 348/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0642 - val_loss: 0.2654 - val_mae: 0.5248
# Epoch 349/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0634 - val_loss: 0.2617 - val_mae: 0.5230
# Epoch 350/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2652 - val_mae: 0.5246
# Epoch 351/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2602 - val_mae: 0.5221
# Epoch 352/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2619 - val_mae: 0.5226
# Epoch 353/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0629 - val_loss: 0.2667 - val_mae: 0.5252
# Epoch 354/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2596 - val_mae: 0.5215
# Epoch 355/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0629 - val_loss: 0.2570 - val_mae: 0.5202
# Epoch 356/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0635 - val_loss: 0.2620 - val_mae: 0.5228
# Epoch 357/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - mae: 0.0628 - val_loss: 0.2649 - val_mae: 0.5240
# Epoch 358/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2586 - val_mae: 0.5207
# Epoch 359/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0630 - val_loss: 0.2617 - val_mae: 0.5222
# Epoch 360/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0629 - val_loss: 0.2627 - val_mae: 0.5226
# Epoch 361/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2625 - val_mae: 0.5223
# Epoch 362/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2601 - val_mae: 0.5209
# Epoch 363/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0028 - mae: 0.0633 - val_loss: 0.2589 - val_mae: 0.5201
# Epoch 364/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2634 - val_mae: 0.5222
# Epoch 365/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0633 - val_loss: 0.2580 - val_mae: 0.5195
# Epoch 366/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0633 - val_loss: 0.2631 - val_mae: 0.5219
# Epoch 367/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0634 - val_loss: 0.2562 - val_mae: 0.5183
# Epoch 368/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0637 - val_loss: 0.2629 - val_mae: 0.5216
# Epoch 369/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2602 - val_mae: 0.5199
# Epoch 370/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2564 - val_mae: 0.5178
# Epoch 371/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0632 - val_loss: 0.2616 - val_mae: 0.5203
# Epoch 372/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2576 - val_mae: 0.5182
# Epoch 373/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2573 - val_mae: 0.5177
# Epoch 374/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0635 - val_loss: 0.2578 - val_mae: 0.5177
# Epoch 375/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2651 - val_mae: 0.5216
# Epoch 376/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0624 - val_loss: 0.2618 - val_mae: 0.5194
# Epoch 377/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2557 - val_mae: 0.5166
# Epoch 378/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - mae: 0.0633 - val_loss: 0.2572 - val_mae: 0.5172
# Epoch 379/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - mae: 0.0623 - val_loss: 0.2640 - val_mae: 0.5208
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0618 - val_loss: 0.2570 - val_mae: 0.5168
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0637 - val_loss: 0.2508 - val_mae: 0.5137
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2610 - val_mae: 0.5187
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2629 - val_mae: 0.5199
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0621 - val_loss: 0.2619 - val_mae: 0.5191
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0628 - val_loss: 0.2539 - val_mae: 0.5150
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2600 - val_mae: 0.5180
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0028 - mae: 0.0616 - val_loss: 0.2639 - val_mae: 0.5204
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2558 - val_mae: 0.5156
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2555 - val_mae: 0.5153
# Epoch 390/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2587 - val_mae: 0.5167
# Epoch 391/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0622 - val_loss: 0.2621 - val_mae: 0.5186
# Epoch 392/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2549 - val_mae: 0.5146
# Epoch 393/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2550 - val_mae: 0.5145
# Epoch 394/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2615 - val_mae: 0.5179
# Epoch 395/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2557 - val_mae: 0.5146
# Epoch 396/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2545 - val_mae: 0.5141
# Epoch 397/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0629 - val_loss: 0.2584 - val_mae: 0.5160
# Epoch 398/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0621 - val_loss: 0.2615 - val_mae: 0.5178
# Epoch 399/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0029 - mae: 0.0634 - val_loss: 0.2536 - val_mae: 0.5134
# Epoch 400/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2574 - val_mae: 0.5155
# Epoch 401/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2602 - val_mae: 0.5169
# Epoch 402/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0029 - mae: 0.0649 - val_loss: 0.2521 - val_mae: 0.5127
# Epoch 403/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0632 - val_loss: 0.2596 - val_mae: 0.5164
# Epoch 404/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0620 - val_loss: 0.2575 - val_mae: 0.5153
# Epoch 405/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0635 - val_loss: 0.2537 - val_mae: 0.5133
# Epoch 406/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0631 - val_loss: 0.2607 - val_mae: 0.5168
# Epoch 407/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0632 - val_loss: 0.2563 - val_mae: 0.5144
# Epoch 408/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2561 - val_mae: 0.5143
# Epoch 409/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2558 - val_mae: 0.5141
# Epoch 410/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0629 - val_loss: 0.2592 - val_mae: 0.5156
# Epoch 411/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2547 - val_mae: 0.5131
# Epoch 412/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2514 - val_mae: 0.5115
# Epoch 413/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2573 - val_mae: 0.5142
# Epoch 414/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2568 - val_mae: 0.5140
# Epoch 415/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2576 - val_mae: 0.5144
# Epoch 416/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2537 - val_mae: 0.5123
# Epoch 417/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0028 - mae: 0.0630 - val_loss: 0.2545 - val_mae: 0.5126
# Epoch 418/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0622 - val_loss: 0.2582 - val_mae: 0.5143
# Epoch 419/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0620 - val_loss: 0.2546 - val_mae: 0.5124
# Epoch 420/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0030 - mae: 0.0649 - val_loss: 0.2518 - val_mae: 0.5108
# Epoch 421/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0029 - mae: 0.0630 - val_loss: 0.2613 - val_mae: 0.5164
# Epoch 422/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0028 - mae: 0.0620 - val_loss: 0.2538 - val_mae: 0.5121
# Epoch 423/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2520 - val_mae: 0.5112
# Epoch 424/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2546 - val_mae: 0.5124
# Epoch 425/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0028 - mae: 0.0620 - val_loss: 0.2578 - val_mae: 0.5141
# Epoch 426/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0622 - val_loss: 0.2561 - val_mae: 0.5130
# Epoch 427/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0633 - val_loss: 0.2494 - val_mae: 0.5095
# Epoch 428/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0631 - val_loss: 0.2552 - val_mae: 0.5124
# Epoch 429/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0621 - val_loss: 0.2603 - val_mae: 0.5156
# Epoch 430/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0621 - val_loss: 0.2543 - val_mae: 0.5122
# Epoch 431/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2548 - val_mae: 0.5128
# Epoch 432/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2518 - val_mae: 0.5116
# Epoch 433/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0028 - mae: 0.0629 - val_loss: 0.2579 - val_mae: 0.5150
# Epoch 434/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0621 - val_loss: 0.2591 - val_mae: 0.5158
# Epoch 435/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0639 - val_loss: 0.2543 - val_mae: 0.5133
# Epoch 436/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2568 - val_mae: 0.5148
# Epoch 437/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0621 - val_loss: 0.2588 - val_mae: 0.5159
# Epoch 438/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029 - mae: 0.0635 - val_loss: 0.2521 - val_mae: 0.5124
# Epoch 439/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2591 - val_mae: 0.5157
# Epoch 440/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0621 - val_loss: 0.2545 - val_mae: 0.5133
# Epoch 441/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2552 - val_mae: 0.5136
# Epoch 442/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2547 - val_mae: 0.5132
# Epoch 443/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2573 - val_mae: 0.5145
# Epoch 444/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2540 - val_mae: 0.5126
# Epoch 445/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2551 - val_mae: 0.5130
# Epoch 446/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2567 - val_mae: 0.5139
# Epoch 447/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2548 - val_mae: 0.5130
# Epoch 448/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2569 - val_mae: 0.5138
# Epoch 449/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2564 - val_mae: 0.5133
# Epoch 450/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0621 - val_loss: 0.2535 - val_mae: 0.5119
# Epoch 451/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0634 - val_loss: 0.2519 - val_mae: 0.5109
# Epoch 452/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0628 - val_loss: 0.2604 - val_mae: 0.5157
# Epoch 453/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0618 - val_loss: 0.2524 - val_mae: 0.5113
# Epoch 454/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0643 - val_loss: 0.2510 - val_mae: 0.5106
# Epoch 455/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0027 - mae: 0.0608 - val_loss: 0.2629 - val_mae: 0.5174
# Epoch 456/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0030 - mae: 0.0618 - val_loss: 0.2570 - val_mae: 0.5135
# Epoch 457/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0030 - mae: 0.0640 - val_loss: 0.2463 - val_mae: 0.5078
# Epoch 458/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0629 - val_loss: 0.2584 - val_mae: 0.5141
# Epoch 459/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0620 - val_loss: 0.2597 - val_mae: 0.5152
# Epoch 460/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - mae: 0.0612 - val_loss: 0.2500 - val_mae: 0.5101
# Epoch 461/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0030 - mae: 0.0648 - val_loss: 0.2500 - val_mae: 0.5103
# Epoch 462/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - mae: 0.0644 - val_loss: 0.2609 - val_mae: 0.5163
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0621 - val_loss: 0.2524 - val_mae: 0.5115
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0641 - val_loss: 0.2520 - val_mae: 0.5113
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0627 - val_loss: 0.2613 - val_mae: 0.5166
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0028 - mae: 0.0619 - val_loss: 0.2518 - val_mae: 0.5109
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0634 - val_loss: 0.2530 - val_mae: 0.5114
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2533 - val_mae: 0.5117
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2548 - val_mae: 0.5124
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0621 - val_loss: 0.2580 - val_mae: 0.5143
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2527 - val_mae: 0.5117
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2553 - val_mae: 0.5132
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2560 - val_mae: 0.5135
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0622 - val_loss: 0.2566 - val_mae: 0.5137
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2523 - val_mae: 0.5115
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2544 - val_mae: 0.5123
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2527 - val_mae: 0.5115
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0629 - val_loss: 0.2573 - val_mae: 0.5135
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mae: 0.0633 - val_loss: 0.2508 - val_mae: 0.5100
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2563 - val_mae: 0.5126
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0030 - mae: 0.0634 - val_loss: 0.2583 - val_mae: 0.5138
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0027 - mae: 0.0607 - val_loss: 0.2485 - val_mae: 0.5086
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0640 - val_loss: 0.2510 - val_mae: 0.5098
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0028 - mae: 0.0626 - val_loss: 0.2612 - val_mae: 0.5158
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0029 - mae: 0.0621 - val_loss: 0.2554 - val_mae: 0.5122
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - mae: 0.0639 - val_loss: 0.2506 - val_mae: 0.5099
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0633 - val_loss: 0.2576 - val_mae: 0.5134
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0028 - mae: 0.0619 - val_loss: 0.2551 - val_mae: 0.5120
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0028 - mae: 0.0627 - val_loss: 0.2518 - val_mae: 0.5103
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2553 - val_mae: 0.5123
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0619 - val_loss: 0.2557 - val_mae: 0.5124
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0620 - val_loss: 0.2522 - val_mae: 0.5109
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0628 - val_loss: 0.2524 - val_mae: 0.5108
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2552 - val_mae: 0.5121
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2535 - val_mae: 0.5112
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2572 - val_mae: 0.5132
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0619 - val_loss: 0.2540 - val_mae: 0.5114
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0623 - val_loss: 0.2532 - val_mae: 0.5113
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0028 - mae: 0.0624 - val_loss: 0.2557 - val_mae: 0.5125
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mae: 0.0625 - val_loss: 0.2528 - val_mae: 0.5110
# Valid MAE sin normalizar (LSTM-32): 0.507757842540741
# Valid MAE (LSTM-32): 1,159,316 votos/5min
