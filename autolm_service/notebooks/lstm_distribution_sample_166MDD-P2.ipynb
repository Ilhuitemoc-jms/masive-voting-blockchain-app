# %%
import numpy as np
import pandas as pd

def distribuir_votos_por_hora(total_votos=166470734, minutos_por_grupo=10, seed=42, suavidad=5):
    """
    Distribuye votos de una jornada electoral en grupos de tiempo.

    Implementa distribución por hora usando porcentajes de Caltech (2015),
    luego distribuye suavemente cada hora entre sus grupos de tiempo 
    usando Dirichlet no-homogéneo.

    Parámetros:
    -----------
    total_votos : int
        Número total de votos a distribuir (default: 166,470,734)
    minutos_por_grupo : int
        Minutos que representa cada grupo: 10, 5, o 1 (default: 10)
    seed : int
        Semilla para reproducibilidad (default: 42)
    suavidad : int
        Parámetro de concentración Dirichlet (mayor = más uniforme, default: 5)

    Retorna:
    --------
    pd.DataFrame con columnas:
        - voting_hour_12: índice del grupo (0 a num_grupos-1)
        - total_votos: cantidad de votos en ese grupo
    """

    # Establecer semilla para reproducibilidad en experimentos
    np.random.seed(seed)

    # Porcentajes de Caltech 2015 por hora (7 AM a 7 PM, 12 horas totales)
    percentages_caltech = np.array([
        15.6,  # 7-8 AM (antes de 8)
        8.7,   # 8-9 AM
        9.5,   # 9-10 AM
        11.2,  # 10-11 AM
        8.7,   # 11-12 PM
        10.8,   # 12-1 PM
        4.5,   # 1-2 PM
        4.2,   # 2-3 PM
        4.3,   # 3-4 PM
        4.2,   # 4-5 PM
        16.2,   # 5-6 PM
        2.1,   # 6-7 PM
    ])

    # Normalizar porcentajes para garantizar suma exacta de 100%
    percentages_caltech = percentages_caltech / percentages_caltech.sum() * 100

    # Obtener número de horas en la jornada electoral
    num_horas = len(percentages_caltech)

    # Calcular cantidad de votos por hora basado en porcentajes de Caltech
    votos_por_hora = (percentages_caltech / 100) * total_votos
    votos_por_hora = votos_por_hora.astype(int)

    # Ajustar primer hora para asegurar que suma total sea exacta
    votos_por_hora[0] += total_votos - votos_por_hora.sum()

    # Calcular número total de grupos y grupos por cada hora
    minutos_jornada = num_horas * 60
    num_grupos_total = int(minutos_jornada // minutos_por_grupo)
    grupos_por_hora = int(60 // minutos_por_grupo)

    # Inicializar array para almacenar distribución de votos por grupo
    votos_grupo = np.zeros(num_grupos_total, dtype=int)

    # Iterar sobre cada hora para distribuir sus votos en sus grupos
    for hora in range(num_horas):
        # Calcular índices de inicio y fin para grupos de esta hora
        inicio = hora * grupos_por_hora
        fin = inicio + grupos_por_hora

        # Generar proporciones aleatorias suaves con distribución Dirichlet
        # Dirichlet proporciona un patrón no-homogéneo sin variaciones bruscas
        parametro_dirichlet = np.ones(grupos_por_hora) * suavidad
        proporciones = np.random.dirichlet(parametro_dirichlet)

        # Distribuir votos de esta hora entre sus grupos usando proporciones
        votos_distribuidos = (proporciones * votos_por_hora[hora]).astype(int)

        # Ajustar primer grupo de hora para mantener exactitud en suma
        diferencia = votos_por_hora[hora] - votos_distribuidos.sum()
        votos_distribuidos[0] += diferencia

        # Asignar votos distribuidos a los grupos de esta hora
        votos_grupo[inicio:fin] = votos_distribuidos

    # Crear DataFrame con estructura requerida para LSTM
    df = pd.DataFrame({
        'voting_hour_12': np.arange(num_grupos_total),
        'total_votos': votos_grupo
    })

    return df


# EJEMPLO 1: Distribución con grupos de 10 minutos (72 grupos)
#df_10min = distribuir_votos_por_hora(minutos_por_grupo=10, seed=42)
#print("Distribución con 10 minutos por grupo:")
#print(f"- Número de grupos: {len(df_10min)}")
#print(f"- Total de votos: {df_10min['total_votos'].sum():,}")
#print(f"\nPrimeras 6 filas (primera hora):\n{df_10min.head(10)}")

## EJEMPLO 2: Distribución con grupos de 5 minutos (144 grupos)
#df_5min = distribuir_votos_por_hora(minutos_por_grupo=5, seed=42)
#print(f"\nDistribución con 5 minutos por grupo:")
#print(f"- Número de grupos: {len(df_5min)}")

## EJEMPLO 3: Distribución con grupos de 1 minuto (720 grupos)
#df_1min = distribuir_votos_por_hora(minutos_por_grupo=1, seed=42)
#print(f"\nDistribución con 1 minuto por grupo:")
#print(f"- Número de grupos: {len(df_1min)}")

# EJEMPLO 4: Cambiar parámetro de suavidad para variar aleatoridad
#df_suave = distribuir_votos_por_hora(minutos_por_grupo=5, suavidad=25, seed=42)
#print(f"\nDistribución con suavidad=20 (más uniforme):")
#print(f"Desviación estándar de votos: {df_suave['total_votos'].std():,.0f}")

#df_brusco = distribuir_votos_por_hora(minutos_por_grupo=10, suavidad=1, seed=42)
#print(f"\nDistribución con suavidad=1 (más variable):")
#print(f"Desviación estándar de votos: {df_brusco['total_votos'].std():,.0f}")

# %%
# EJEMPLO 1: Distribución con grupos de 10 minutos (72 grupos)
df_prueba = distribuir_votos_por_hora(minutos_por_grupo=5, suavidad=30, seed=42)
print("Distribución con 5 minutos por grupo:")
print(f"- Número de grupos: {len(df_prueba)}")
#print(f"- Total de votos: {df_5_suave['total_votos'].sum():,}")
print(f"\nPrimeras 12 filas (primera hora):\n{df_prueba.head(12)}")
# Out:
# Distribución con 5 minutos por grupo:
# - Número de grupos: 144
#
# Primeras 12 filas (primera hora):
#     voting_hour_12  total_votos
# 0                0      2350452
# 1                1      2094418
# 2                2      2057451
# 3                3      2057457
# 4                4      2833573
# 5                5      2465658
# 6                6      1968579
# 7                7      2369699
# 8                8      2245361
# 9                9      1478709
# 10              10      1773230
# 11              11      2274854

# %%
import matplotlib.pyplot as plt
import numpy as np

# Correr la serie
df = distribuir_votos_por_hora(minutos_por_grupo=5, suavidad=30, seed=42)

# Extraer datos del DataFrame (tu df se llama 'df')
groups = df['voting_hour_12'].values   # Grupos de 0 a 71
series = df['total_votos'].values      # Cantidad de votos por grupo

# Crear figura más grande para 72 puntos
plt.figure(figsize=(18, 7))

# Plotear la serie de tiempo
plt.plot(groups, series, marker='o', linewidth=1.5, markersize=4, 
         color='#2E86AB', label='Votos por Grupo de 5 min en 12 hrs')

# Personalización
plt.xlabel('Grupo de 5 Minutos (0-143)', fontsize=12, fontweight='bold')
plt.ylabel('Total de Votos', fontsize=12, fontweight='bold')
plt.title('Distribución Temporal de 166,470,734 Votos por Grupos de 5 Minutos\n(Hora 5:00 AM - 4:59 PM)', 
          fontsize=14, fontweight='bold')

# Configurar el eje X para mostrar cada grupo
plt.xticks(range(0, 144, 12), fontsize=9)  # Mostrar cada 6 grupos (cada hora)
plt.grid(True, alpha=0.3, linestyle='--')
plt.legend(fontsize=11, loc='upper left')

# Agregar líneas verticales cada hora (cada 12 grupos)
for h in range(0, 144, 12):
    plt.axvline(x=h, color='gray', linestyle=':', alpha=0.5, linewidth=0.8)

# Agregar etiquetas de hora en el eje X secundario
ax = plt.gca()
ax2 = ax.twiny()
ax2.set_xlim(ax.get_xlim())
hora_labels = [f'{5+i}:00' for i in range(12)]  # De 5:00 AM a 16:00 (4 PM)
ax2.set_xticks(range(0, 144, 12))
ax2.set_xticklabels(hora_labels, fontsize=9)
ax2.set_xlabel('Hora del Día', fontsize=11, fontweight='bold')

# Mostrar valores solo en puntos clave (cada 12 grupos)
for i in range(0, len(groups), 6):
    plt.text(groups[i], series[i] + max(series)*0.02, 
             f'{int(series[i]):,}', ha='center', fontsize=8, rotation=45)

plt.tight_layout()
plt.show()

print(f"\nEstadísticas del gráfico:")
print(f"  - Total de grupos: {len(groups)}")
print(f"  - Rango de grupos: {groups.min()} a {groups.max()}")
print(f"  - Total de votos: {series.sum():,}")
# Out:
# Estadísticas del gráfico:
#   - Total de grupos: 144
#   - Rango de grupos: 0 a 143
#   - Total de votos: 166,470,734

# %%
df
# Out:
#      voting_hour_12  total_votos
# 0                 0      2350452
# 1                 1      2094418
# 2                 2      2057451
# 3                 3      2057457
# 4                 4      2833573
# ..              ...          ...
# 139             139       336526
# 140             140       300301
# 141             141       263577
# 142             142       200232
# 143             143       308113
#
# [144 rows x 2 columns]

# %%
# Índice para el 80%
index_80 = int(len(series) * 0.6)
# Índice para el 90% (80% + 10%) y el 10% restante
index_90 = int(len(series) * 0.75)

# Partimos la serie en función de las proporciones
train = series[:index_80]               #Entrenamiento
valid = series[index_80:index_90]             #Validación
test  = series[index_90:]              #Prueba 

#Ahora hacemos el proceso de normalización, esto poniendo los datos dentro de una escala entre 0 y 1
# 1) Tomamos la “escala” como el valor máximo observado en TRAIN
scale = float(train.max()) if float(train.max()) != 0 else 1.0

# 2) Divides cada serie por la escala → todo queda en ~[0, 1]
y_train = (train / scale).astype('float32')
y_valid = (valid / scale).astype('float32')
y_test  = (test  / scale).astype('float32')

print("Grupos definidos")
print("[Entrenamiento, validación y prueba]")
grupos = [y_train, y_valid, y_test]
grupos
# Out:
# Grupos definidos
# [Entrenamiento, validación y prueba]
# [array([0.82950115, 0.73914385, 0.72609776, 0.72609985, 1.        ,
#         0.8701586 , 0.6947338 , 0.83629364, 0.7924133 , 0.52185315,
#         0.6257929 , 0.80282176, 0.5703082 , 0.42273024, 0.39814857,
#         0.44978583, 0.39390975, 0.41756397, 0.43965763, 0.36057937,
#         0.5107163 , 0.34915528, 0.34177133, 0.4568716 , 0.5059919 ,
#         0.45724037, 0.43380812, 0.4191016 , 0.40671936, 0.53484416,
#         0.47004542, 0.41255262, 0.39032593, 0.4948039 , 0.5324384 ,
#         0.5233216 , 0.45553935, 0.5038797 , 0.48802236, 0.5156204 ,
#         0.61722815, 0.6778043 , 0.56982154, 0.47286412, 0.5301007 ,
#         0.7020341 , 0.54217625, 0.50484246, 0.4034694 , 0.44834277,
#         0.36085078, 0.38265538, 0.49483567, 0.44606227, 0.42772076,
#         0.49943057, 0.3683205 , 0.3954128 , 0.44344756, 0.44064966,
#         0.40267357, 0.48867032, 0.51294565, 0.5686181 , 0.55382305,
#         0.52124965, 0.3632848 , 0.5258714 , 0.53430456, 0.80526   ,
#         0.5099957 , 0.55823904, 0.27316326, 0.25524524, 0.28552854,
#         0.17040253, 0.18486907, 0.20062515, 0.16536048, 0.22583748,
#         0.18745062, 0.29269123, 0.1924602 , 0.21008952, 0.23946762,
#         0.16364498], dtype=float32),
#  array([0.15171023, 0.2140813 , 0.21701929, 0.23814033, 0.22746052,
#         0.21847752, 0.18220353, 0.21593761, 0.21832365, 0.18100822,
#         0.27111706, 0.21356323, 0.1629868 , 0.22572349, 0.23276548,
#         0.21124531, 0.18731333, 0.17011914, 0.19325072, 0.2085473 ,
#         0.19648056, 0.25311187], dtype=float32),
#  array([0.24064387, 0.18289912, 0.17542869, 0.23459992, 0.20628797,
#         0.24442038, 0.23421383, 0.21212652, 0.18326649, 0.16056724,
#         0.22354992, 0.16947085, 0.59235674, 0.7198364 , 0.707403  ,
#         0.5630598 , 0.84849554, 0.8442295 , 0.768186  , 0.76801515,
#         0.7681877 , 1.3208723 , 0.829781  , 0.7869806 , 0.09088208,
#         0.1005942 , 0.15638594, 0.07302794, 0.09625198, 0.1275411 ,
#         0.0918907 , 0.11876383, 0.10597962, 0.09301931, 0.07066414,
#         0.10873657], dtype=float32)]

# %%
import tensorflow as tf
tf.random.set_seed(42)

# tamaño de la secuencia optima.
seq_length = 13
#max(2, min(56, len(y_train) - 1, len(y_valid) - 1, len(y_test) - 1))
print(seq_length)
batch_size = 16

# Función para calcular las ventanas deslizantes, la ventana maxima viable
def make_ds(series_1d, seq_len, batch=16, shuffle_input=False, seed=42):
    return tf.keras.utils.timeseries_dataset_from_array(
        data=series_1d,                # serie, ya normalizada.
        targets=series_1d[seq_len:],   # targets=series_1d[seq_len:]: define que el modelo aprende a predecir el siguiente punto a partir de la ventana de tamaño seq_len.
        sequence_length=seq_len,       # el tamaño de la ventana que tendra la mini serie de tiempo  
        batch_size=batch,              # se divide el anterior dato en 32 aleatoriamente con la semilla
        shuffle=shuffle_input,         # si se revuelve o no los datos, si es aleatoria esta batch de 32 a partir de los targets
        seed=seed                      # para asegurar reproducibilidad
    )

train_ds = make_ds(y_train, seq_length, batch_size, shuffle_input=True,  seed=42)  #se combinan para que aprenda de diferentes puntos la red
valid_ds = make_ds(y_valid, seq_length, batch_size, shuffle_input=False)           #no se combinan porque solo se predice directamente para obtener el valor de la metrica
test_ds  = make_ds(y_test,  seq_length, batch_size, shuffle_input=False)           #igual que arriba

print("seq_length usado:", seq_length)
print(train_ds)
# Out:
# 13
# seq_length usado: 13
# <_BatchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
def fit_and_evaluate(model, train_set, valid_set, learning_rate, epochs=300):
    """
    Entrena un modelo recurrente para predecir t+1.
    
    Argumentos:
        model: Modelo LSTM/RNN de Keras
        train_set: Dataset de entrenamiento (ventanas deslizantes)
        valid_set: Dataset de validación
        learning_rate: Tasa de aprendizaje para SGD
        epochs: Número máximo de épocas (iteraciones completas sobre los datos)
    
    Retorna:
        history: Historial de entrenamiento (pérdidas, métricas)
        val_mae: MAE en validación (en unidades originales, no normalizadas)
    """
    
    # Early Stopping: Detiene entrenamiento si no mejora en 50 épocas
            # Previene sobre ajuste
    cb = tf.keras.callbacks.EarlyStopping(
        monitor="val_mae",           # Métrica a monitorear
        patience=50,                 # Épocas sin mejora antes de detener
        restore_best_weights=True    # Restaura pesos de la mejor época
    )
    
    # Optimizador Stochastic Gradient Descent (SGD) con momentum
    opt = tf.keras.optimizers.SGD(
        learning_rate=learning_rate,  # Tamaño del paso en la dirección del gradiente, muy alto modelo diverge, muy bajo convergencia lenta
        momentum=0.9                  # Inercia (acelera convergencia, típicamente entre 0.9-0.99), Acelera convergencia y ayuda a escapar de mínimos locales poco profundos
    )
    
    # Compilación del modelo
    model.compile(
        loss=tf.keras.losses.Huber(),  # Función híbrida que combina MSE (errores pequeños) y MAE (errores grandes), más robusta (para la compilación)
        optimizer=opt,                 # Algoritmo de optimización
        metrics=["mae"]                # Métricas adicionales a reportar   (la que se usa para compara con otros modelos)
    )
    
    # Entrenamiento
    history = model.fit(
        train_set,                    # Datos de entrenamiento
        validation_data=valid_set,    # Datos de validación
        epochs=epochs,                # Épocas máximas
        callbacks=[cb],               # Lista de callbacks
        verbose=1                     # Mostrar progreso, imprimir la salida (imprimir más)
    )
    
    # Evaluación final en validación
    _, val_mae = model.evaluate(valid_set, verbose=0)
    
    # Desnormalizar MAE
    return history, float(val_mae) * scale   # reescala a votos/hora, multimplicamos por la escala hecha anteriormente

print("Función fit_and_evaluate() definida")
# Out:
# Función fit_and_evaluate() definida

# %% [markdown]
# ### Ejemplo de Salida del siguiente código, es necesario describir que está pasando
#
# - Epoch 100/300
# - 45/45 [==============================] - 0s 3ms/step - loss: 0.0045 - mae: 0.0045 - val_loss: 0.0042 - val_mae: 0.0042
# - Epoch 150/300
#
# ¿Qué significa cada cosa?
# - loss (perdida)  :Huber loss en el entrenamiento (dato normalizado)
# - mae             :Error Medio absoluto (Normalizado)
# - val_loss:       :Huber loss en validación
# - val_mae:        :MAE en validación (encargado de monitorear Early Stopping)

# %%
tf.random.set_seed(42)

model_lstm = tf.keras.Sequential([
    tf.keras.layers.LSTM(
        16,                              #Dimension de las capas ocultas, entre más, también más riesgo de overfitting
        input_shape=[None, 1]),          #NONE es aceptar secuencias de cualquier longitud, el tamño de la ventana #1 es el no de caracteristicas por paso, y solo analizamos los votos
    tf.keras.layers.Dense(1)             #Solo se predice un dato de salida, la cantidad de votos en t+1 (la estructura es una unica salida y una sola capa densa)
])

hist_lstm, valid_mae_lstm = fit_and_evaluate(model_lstm, train_ds, test_ds, learning_rate=0.05, epochs=500)

print(f"Valid MAE sin normalizar (LSTM-32): {valid_mae_lstm/scale}")
print(f"Valid MAE (LSTM-32): {valid_mae_lstm:,.0f} votos/5min")
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0365 - mae: 0.2195 - val_loss: 0.0766 - val_mae: 0.3255
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0320 - mae: 0.2291 - val_loss: 0.0564 - val_mae: 0.3100
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0189 - mae: 0.1571 - val_loss: 0.0704 - val_mae: 0.3033
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0102 - mae: 0.1123 - val_loss: 0.0584 - val_mae: 0.3029
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0126 - mae: 0.1293 - val_loss: 0.0526 - val_mae: 0.2972
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0061 - mae: 0.0849 - val_loss: 0.0564 - val_mae: 0.2921
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0080 - mae: 0.1038 - val_loss: 0.0509 - val_mae: 0.2897
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0062 - mae: 0.0854 - val_loss: 0.0501 - val_mae: 0.2860
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0058 - mae: 0.0838 - val_loss: 0.0498 - val_mae: 0.2818
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0059 - mae: 0.0862 - val_loss: 0.0489 - val_mae: 0.2785
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0059 - mae: 0.0851 - val_loss: 0.0479 - val_mae: 0.2755
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0055 - mae: 0.0828 - val_loss: 0.0477 - val_mae: 0.2716
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0056 - mae: 0.0837 - val_loss: 0.0470 - val_mae: 0.2686
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053 - mae: 0.0799 - val_loss: 0.0461 - val_mae: 0.2660
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0055 - mae: 0.0815 - val_loss: 0.0456 - val_mae: 0.2629
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0055 - mae: 0.0820 - val_loss: 0.0457 - val_mae: 0.2601
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0054 - mae: 0.0806 - val_loss: 0.0447 - val_mae: 0.2579
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0052 - mae: 0.0802 - val_loss: 0.0443 - val_mae: 0.2552
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0051 - mae: 0.0795 - val_loss: 0.0441 - val_mae: 0.2525
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0051 - mae: 0.0795 - val_loss: 0.0435 - val_mae: 0.2505
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0051 - mae: 0.0784 - val_loss: 0.0432 - val_mae: 0.2484
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0050 - mae: 0.0780 - val_loss: 0.0431 - val_mae: 0.2461
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0050 - mae: 0.0783 - val_loss: 0.0426 - val_mae: 0.2440
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0049 - mae: 0.0775 - val_loss: 0.0422 - val_mae: 0.2418
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0049 - mae: 0.0771 - val_loss: 0.0419 - val_mae: 0.2396
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0049 - mae: 0.0772 - val_loss: 0.0416 - val_mae: 0.2375
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0049 - mae: 0.0770 - val_loss: 0.0414 - val_mae: 0.2357
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0048 - mae: 0.0759 - val_loss: 0.0411 - val_mae: 0.2340
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0048 - mae: 0.0762 - val_loss: 0.0408 - val_mae: 0.2322
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0048 - mae: 0.0761 - val_loss: 0.0406 - val_mae: 0.2302
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mae: 0.0765 - val_loss: 0.0404 - val_mae: 0.2284
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0049 - mae: 0.0773 - val_loss: 0.0401 - val_mae: 0.2270
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0048 - mae: 0.0766 - val_loss: 0.0400 - val_mae: 0.2252
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mae: 0.0755 - val_loss: 0.0397 - val_mae: 0.2241
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0050 - mae: 0.0780 - val_loss: 0.0395 - val_mae: 0.2230
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0046 - mae: 0.0741 - val_loss: 0.0396 - val_mae: 0.2211
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0049 - mae: 0.0757 - val_loss: 0.0392 - val_mae: 0.2199
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0048 - mae: 0.0777 - val_loss: 0.0389 - val_mae: 0.2188
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0047 - mae: 0.0745 - val_loss: 0.0388 - val_mae: 0.2171
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0047 - mae: 0.0747 - val_loss: 0.0385 - val_mae: 0.2160
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0046 - mae: 0.0734 - val_loss: 0.0383 - val_mae: 0.2149
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0047 - mae: 0.0745 - val_loss: 0.0382 - val_mae: 0.2137
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0046 - mae: 0.0742 - val_loss: 0.0381 - val_mae: 0.2125
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0047 - mae: 0.0740 - val_loss: 0.0379 - val_mae: 0.2113
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0047 - mae: 0.0742 - val_loss: 0.0377 - val_mae: 0.2103
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0046 - mae: 0.0740 - val_loss: 0.0375 - val_mae: 0.2092
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0045 - mae: 0.0733 - val_loss: 0.0375 - val_mae: 0.2083
# Epoch 48/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0047 - mae: 0.0744 - val_loss: 0.0372 - val_mae: 0.2075
# Epoch 49/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0046 - mae: 0.0734 - val_loss: 0.0371 - val_mae: 0.2066
# Epoch 50/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0045 - mae: 0.0729 - val_loss: 0.0369 - val_mae: 0.2057
# Epoch 51/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0045 - mae: 0.0735 - val_loss: 0.0367 - val_mae: 0.2049
# Epoch 52/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0046 - mae: 0.0738 - val_loss: 0.0366 - val_mae: 0.2039
# Epoch 53/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0045 - mae: 0.0729 - val_loss: 0.0364 - val_mae: 0.2029
# Epoch 54/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0045 - mae: 0.0732 - val_loss: 0.0363 - val_mae: 0.2019
# Epoch 55/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0044 - mae: 0.0719 - val_loss: 0.0362 - val_mae: 0.2009
# Epoch 56/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0045 - mae: 0.0726 - val_loss: 0.0361 - val_mae: 0.2001
# Epoch 57/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0046 - mae: 0.0728 - val_loss: 0.0359 - val_mae: 0.1996
# Epoch 58/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0046 - mae: 0.0738 - val_loss: 0.0358 - val_mae: 0.1986
# Epoch 59/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0045 - mae: 0.0718 - val_loss: 0.0356 - val_mae: 0.1978
# Epoch 60/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0045 - mae: 0.0729 - val_loss: 0.0354 - val_mae: 0.1970
# Epoch 61/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0045 - mae: 0.0729 - val_loss: 0.0354 - val_mae: 0.1962
# Epoch 62/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0045 - mae: 0.0723 - val_loss: 0.0354 - val_mae: 0.1953
# Epoch 63/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0045 - mae: 0.0740 - val_loss: 0.0350 - val_mae: 0.1945
# Epoch 64/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0044 - mae: 0.0722 - val_loss: 0.0349 - val_mae: 0.1935
# Epoch 65/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0044 - mae: 0.0716 - val_loss: 0.0349 - val_mae: 0.1925
# Epoch 66/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0044 - mae: 0.0715 - val_loss: 0.0347 - val_mae: 0.1918
# Epoch 67/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0044 - mae: 0.0720 - val_loss: 0.0345 - val_mae: 0.1909
# Epoch 68/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0044 - mae: 0.0718 - val_loss: 0.0344 - val_mae: 0.1902
# Epoch 69/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0044 - mae: 0.0713 - val_loss: 0.0344 - val_mae: 0.1892
# Epoch 70/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0044 - mae: 0.0711 - val_loss: 0.0342 - val_mae: 0.1888
# Epoch 71/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - mae: 0.0711 - val_loss: 0.0341 - val_mae: 0.1882
# Epoch 72/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0044 - mae: 0.0727 - val_loss: 0.0339 - val_mae: 0.1870
# Epoch 73/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0044 - mae: 0.0717 - val_loss: 0.0339 - val_mae: 0.1859
# Epoch 74/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - mae: 0.0702 - val_loss: 0.0337 - val_mae: 0.1853
# Epoch 75/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0044 - mae: 0.0716 - val_loss: 0.0336 - val_mae: 0.1847
# Epoch 76/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0044 - mae: 0.0711 - val_loss: 0.0335 - val_mae: 0.1840
# Epoch 77/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - mae: 0.0704 - val_loss: 0.0333 - val_mae: 0.1833
# Epoch 78/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0043 - mae: 0.0718 - val_loss: 0.0332 - val_mae: 0.1827
# Epoch 79/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0044 - mae: 0.0717 - val_loss: 0.0331 - val_mae: 0.1819
# Epoch 80/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0043 - mae: 0.0707 - val_loss: 0.0331 - val_mae: 0.1811
# Epoch 81/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - mae: 0.0707 - val_loss: 0.0329 - val_mae: 0.1804
# Epoch 82/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0043 - mae: 0.0707 - val_loss: 0.0328 - val_mae: 0.1797
# Epoch 83/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - mae: 0.0706 - val_loss: 0.0327 - val_mae: 0.1791
# Epoch 84/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - mae: 0.0703 - val_loss: 0.0326 - val_mae: 0.1785
# Epoch 85/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - mae: 0.0704 - val_loss: 0.0325 - val_mae: 0.1777
# Epoch 86/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0044 - mae: 0.0717 - val_loss: 0.0324 - val_mae: 0.1771
# Epoch 87/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - mae: 0.0709 - val_loss: 0.0323 - val_mae: 0.1763
# Epoch 88/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042 - mae: 0.0699 - val_loss: 0.0322 - val_mae: 0.1761
# Epoch 89/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0044 - mae: 0.0713 - val_loss: 0.0321 - val_mae: 0.1752
# Epoch 90/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - mae: 0.0696 - val_loss: 0.0320 - val_mae: 0.1749
# Epoch 91/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0042 - mae: 0.0697 - val_loss: 0.0319 - val_mae: 0.1742
# Epoch 92/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - mae: 0.0702 - val_loss: 0.0318 - val_mae: 0.1735
# Epoch 93/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0042 - mae: 0.0694 - val_loss: 0.0317 - val_mae: 0.1729
# Epoch 94/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - mae: 0.0696 - val_loss: 0.0316 - val_mae: 0.1722
# Epoch 95/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - mae: 0.0695 - val_loss: 0.0315 - val_mae: 0.1718
# Epoch 96/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - mae: 0.0693 - val_loss: 0.0314 - val_mae: 0.1711
# Epoch 97/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0694 - val_loss: 0.0313 - val_mae: 0.1706
# Epoch 98/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - mae: 0.0695 - val_loss: 0.0313 - val_mae: 0.1701
# Epoch 99/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0042 - mae: 0.0696 - val_loss: 0.0312 - val_mae: 0.1698
# Epoch 100/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0043 - mae: 0.0702 - val_loss: 0.0311 - val_mae: 0.1695
# Epoch 101/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - mae: 0.0690 - val_loss: 0.0310 - val_mae: 0.1689
# Epoch 102/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0043 - mae: 0.0704 - val_loss: 0.0309 - val_mae: 0.1682
# Epoch 103/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0045 - mae: 0.0713 - val_loss: 0.0309 - val_mae: 0.1677
# Epoch 104/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0042 - mae: 0.0690 - val_loss: 0.0307 - val_mae: 0.1687
# Epoch 105/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0695 - val_loss: 0.0306 - val_mae: 0.1664
# Epoch 106/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - mae: 0.0688 - val_loss: 0.0305 - val_mae: 0.1656
# Epoch 107/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0042 - mae: 0.0694 - val_loss: 0.0305 - val_mae: 0.1649
# Epoch 108/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0042 - mae: 0.0693 - val_loss: 0.0304 - val_mae: 0.1664
# Epoch 109/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - mae: 0.0693 - val_loss: 0.0303 - val_mae: 0.1642
# Epoch 110/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0683 - val_loss: 0.0303 - val_mae: 0.1634
# Epoch 111/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - mae: 0.0694 - val_loss: 0.0301 - val_mae: 0.1645
# Epoch 112/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - mae: 0.0691 - val_loss: 0.0300 - val_mae: 0.1638
# Epoch 113/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - mae: 0.0687 - val_loss: 0.0300 - val_mae: 0.1615
# Epoch 114/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - mae: 0.0693 - val_loss: 0.0299 - val_mae: 0.1610
# Epoch 115/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - mae: 0.0684 - val_loss: 0.0298 - val_mae: 0.1629
# Epoch 116/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0042 - mae: 0.0695 - val_loss: 0.0297 - val_mae: 0.1616
# Epoch 117/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0041 - mae: 0.0683 - val_loss: 0.0296 - val_mae: 0.1605
# Epoch 118/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0042 - mae: 0.0693 - val_loss: 0.0296 - val_mae: 0.1600
# Epoch 119/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - mae: 0.0684 - val_loss: 0.0295 - val_mae: 0.1588
# Epoch 120/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0041 - mae: 0.0691 - val_loss: 0.0294 - val_mae: 0.1601
# Epoch 121/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - mae: 0.0685 - val_loss: 0.0293 - val_mae: 0.1581
# Epoch 122/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - mae: 0.0688 - val_loss: 0.0293 - val_mae: 0.1584
# Epoch 123/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - mae: 0.0683 - val_loss: 0.0293 - val_mae: 0.1618
# Epoch 124/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0041 - mae: 0.0682 - val_loss: 0.0291 - val_mae: 0.1563
# Epoch 125/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0693 - val_loss: 0.0292 - val_mae: 0.1551
# Epoch 126/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0042 - mae: 0.0689 - val_loss: 0.0290 - val_mae: 0.1567
# Epoch 127/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041 - mae: 0.0681 - val_loss: 0.0291 - val_mae: 0.1617
# Epoch 128/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042 - mae: 0.0696 - val_loss: 0.0289 - val_mae: 0.1555
# Epoch 129/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0046 - mae: 0.0743 - val_loss: 0.0293 - val_mae: 0.1560
# Epoch 130/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0658 - val_loss: 0.0291 - val_mae: 0.1632
# Epoch 131/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0045 - mae: 0.0738 - val_loss: 0.0287 - val_mae: 0.1590
# Epoch 132/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0041 - mae: 0.0676 - val_loss: 0.0287 - val_mae: 0.1537
# Epoch 133/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - mae: 0.0690 - val_loss: 0.0286 - val_mae: 0.1551
# Epoch 134/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - mae: 0.0678 - val_loss: 0.0285 - val_mae: 0.1559
# Epoch 135/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - mae: 0.0684 - val_loss: 0.0284 - val_mae: 0.1543
# Epoch 136/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0680 - val_loss: 0.0284 - val_mae: 0.1536
# Epoch 137/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - mae: 0.0680 - val_loss: 0.0283 - val_mae: 0.1540
# Epoch 138/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0681 - val_loss: 0.0283 - val_mae: 0.1527
# Epoch 139/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0682 - val_loss: 0.0282 - val_mae: 0.1520
# Epoch 140/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0681 - val_loss: 0.0282 - val_mae: 0.1517
# Epoch 141/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0682 - val_loss: 0.0281 - val_mae: 0.1544
# Epoch 142/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - mae: 0.0701 - val_loss: 0.0281 - val_mae: 0.1509
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0706 - val_loss: 0.0280 - val_mae: 0.1526
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0041 - mae: 0.0683 - val_loss: 0.0279 - val_mae: 0.1511
# Epoch 145/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0040 - mae: 0.0673 - val_loss: 0.0280 - val_mae: 0.1502
# Epoch 146/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0700 - val_loss: 0.0278 - val_mae: 0.1535
# Epoch 147/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - mae: 0.0690 - val_loss: 0.0278 - val_mae: 0.1498
# Epoch 148/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - mae: 0.0691 - val_loss: 0.0278 - val_mae: 0.1494
# Epoch 149/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0688 - val_loss: 0.0278 - val_mae: 0.1491
# Epoch 150/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0682 - val_loss: 0.0277 - val_mae: 0.1533
# Epoch 151/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - mae: 0.0678 - val_loss: 0.0275 - val_mae: 0.1493
# Epoch 152/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0677 - val_loss: 0.0276 - val_mae: 0.1485
# Epoch 153/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0679 - val_loss: 0.0275 - val_mae: 0.1484
# Epoch 154/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0040 - mae: 0.0673 - val_loss: 0.0275 - val_mae: 0.1515
# Epoch 155/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0041 - mae: 0.0684 - val_loss: 0.0274 - val_mae: 0.1479
# Epoch 156/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0676 - val_loss: 0.0273 - val_mae: 0.1488
# Epoch 157/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0678 - val_loss: 0.0273 - val_mae: 0.1492
# Epoch 158/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041 - mae: 0.0685 - val_loss: 0.0272 - val_mae: 0.1483
# Epoch 159/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - mae: 0.0667 - val_loss: 0.0274 - val_mae: 0.1465
# Epoch 160/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - mae: 0.0691 - val_loss: 0.0271 - val_mae: 0.1472
# Epoch 161/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0681 - val_loss: 0.0271 - val_mae: 0.1463
# Epoch 162/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0672 - val_loss: 0.0270 - val_mae: 0.1466
# Epoch 163/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0270 - val_mae: 0.1459
# Epoch 164/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0677 - val_loss: 0.0270 - val_mae: 0.1459
# Epoch 165/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0040 - mae: 0.0675 - val_loss: 0.0269 - val_mae: 0.1458
# Epoch 166/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041 - mae: 0.0686 - val_loss: 0.0269 - val_mae: 0.1474
# Epoch 167/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - mae: 0.0680 - val_loss: 0.0271 - val_mae: 0.1448
# Epoch 168/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041 - mae: 0.0682 - val_loss: 0.0268 - val_mae: 0.1457
# Epoch 169/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0675 - val_loss: 0.0268 - val_mae: 0.1471
# Epoch 170/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0675 - val_loss: 0.0267 - val_mae: 0.1453
# Epoch 171/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0672 - val_loss: 0.0267 - val_mae: 0.1445
# Epoch 172/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0667 - val_loss: 0.0266 - val_mae: 0.1458
# Epoch 173/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0671 - val_loss: 0.0266 - val_mae: 0.1440
# Epoch 174/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0040 - mae: 0.0675 - val_loss: 0.0265 - val_mae: 0.1439
# Epoch 175/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0041 - mae: 0.0680 - val_loss: 0.0265 - val_mae: 0.1459
# Epoch 176/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0040 - mae: 0.0668 - val_loss: 0.0265 - val_mae: 0.1434
# Epoch 177/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0041 - mae: 0.0682 - val_loss: 0.0264 - val_mae: 0.1435
# Epoch 178/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0042 - mae: 0.0690 - val_loss: 0.0265 - val_mae: 0.1472
# Epoch 179/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0041 - mae: 0.0685 - val_loss: 0.0265 - val_mae: 0.1427
# Epoch 180/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0040 - mae: 0.0678 - val_loss: 0.0263 - val_mae: 0.1437
# Epoch 181/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - mae: 0.0676 - val_loss: 0.0262 - val_mae: 0.1432
# Epoch 182/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0671 - val_loss: 0.0262 - val_mae: 0.1425
# Epoch 183/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0040 - mae: 0.0671 - val_loss: 0.0262 - val_mae: 0.1424
# Epoch 184/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0669 - val_loss: 0.0261 - val_mae: 0.1424
# Epoch 185/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0261 - val_mae: 0.1432
# Epoch 186/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0682 - val_loss: 0.0261 - val_mae: 0.1443
# Epoch 187/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0678 - val_loss: 0.0260 - val_mae: 0.1418
# Epoch 188/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0042 - mae: 0.0683 - val_loss: 0.0262 - val_mae: 0.1414
# Epoch 189/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - mae: 0.0691 - val_loss: 0.0261 - val_mae: 0.1453
# Epoch 190/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0686 - val_loss: 0.0261 - val_mae: 0.1412
# Epoch 191/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040 - mae: 0.0671 - val_loss: 0.0260 - val_mae: 0.1411
# Epoch 192/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0040 - mae: 0.0675 - val_loss: 0.0260 - val_mae: 0.1428
# Epoch 193/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0682 - val_loss: 0.0259 - val_mae: 0.1417
# Epoch 194/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0668 - val_loss: 0.0261 - val_mae: 0.1407
# Epoch 195/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - mae: 0.0682 - val_loss: 0.0259 - val_mae: 0.1409
# Epoch 196/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0044 - mae: 0.0718 - val_loss: 0.0262 - val_mae: 0.1456
# Epoch 197/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0680 - val_loss: 0.0261 - val_mae: 0.1404
# Epoch 198/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0042 - mae: 0.0682 - val_loss: 0.0258 - val_mae: 0.1402
# Epoch 199/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - mae: 0.0690 - val_loss: 0.0260 - val_mae: 0.1442
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0041 - mae: 0.0697 - val_loss: 0.0257 - val_mae: 0.1402
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040 - mae: 0.0670 - val_loss: 0.0259 - val_mae: 0.1399
# Epoch 202/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0040 - mae: 0.0668 - val_loss: 0.0257 - val_mae: 0.1412
# Epoch 203/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0040 - mae: 0.0682 - val_loss: 0.0257 - val_mae: 0.1406
# Epoch 204/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0669 - val_loss: 0.0257 - val_mae: 0.1396
# Epoch 205/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0040 - mae: 0.0674 - val_loss: 0.0256 - val_mae: 0.1400
# Epoch 206/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0678 - val_loss: 0.0257 - val_mae: 0.1391
# Epoch 207/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0672 - val_loss: 0.0256 - val_mae: 0.1409
# Epoch 208/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0256 - val_mae: 0.1390
# Epoch 209/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0669 - val_loss: 0.0255 - val_mae: 0.1389
# Epoch 210/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0040 - mae: 0.0674 - val_loss: 0.0255 - val_mae: 0.1394
# Epoch 211/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0663 - val_loss: 0.0255 - val_mae: 0.1385
# Epoch 212/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0666 - val_loss: 0.0255 - val_mae: 0.1385
# Epoch 213/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0666 - val_loss: 0.0255 - val_mae: 0.1406
# Epoch 214/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040 - mae: 0.0683 - val_loss: 0.0254 - val_mae: 0.1385
# Epoch 215/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0254 - val_mae: 0.1384
# Epoch 216/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0668 - val_loss: 0.0253 - val_mae: 0.1384
# Epoch 217/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - mae: 0.0667 - val_loss: 0.0253 - val_mae: 0.1384
# Epoch 218/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0682 - val_loss: 0.0253 - val_mae: 0.1394
# Epoch 219/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0040 - mae: 0.0673 - val_loss: 0.0254 - val_mae: 0.1377
# Epoch 220/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0252 - val_mae: 0.1382
# Epoch 221/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0683 - val_loss: 0.0252 - val_mae: 0.1391
# Epoch 222/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0040 - mae: 0.0679 - val_loss: 0.0252 - val_mae: 0.1378
# Epoch 223/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0039 - mae: 0.0665 - val_loss: 0.0252 - val_mae: 0.1380
# Epoch 224/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0039 - mae: 0.0671 - val_loss: 0.0252 - val_mae: 0.1372
# Epoch 225/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0669 - val_loss: 0.0251 - val_mae: 0.1377
# Epoch 226/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0042 - mae: 0.0695 - val_loss: 0.0251 - val_mae: 0.1387
# Epoch 227/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0042 - mae: 0.0687 - val_loss: 0.0253 - val_mae: 0.1374
# Epoch 228/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0251 - val_mae: 0.1385
# Epoch 229/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - mae: 0.0693 - val_loss: 0.0250 - val_mae: 0.1376
# Epoch 230/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0040 - mae: 0.0671 - val_loss: 0.0251 - val_mae: 0.1365
# Epoch 231/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0673 - val_loss: 0.0251 - val_mae: 0.1381
# Epoch 232/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0669 - val_loss: 0.0252 - val_mae: 0.1364
# Epoch 233/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0671 - val_loss: 0.0250 - val_mae: 0.1367
# Epoch 234/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0667 - val_loss: 0.0250 - val_mae: 0.1367
# Epoch 235/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0660 - val_loss: 0.0250 - val_mae: 0.1361
# Epoch 236/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0250 - val_mae: 0.1361
# Epoch 237/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0665 - val_loss: 0.0249 - val_mae: 0.1374
# Epoch 238/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0669 - val_loss: 0.0250 - val_mae: 0.1357
# Epoch 239/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0662 - val_loss: 0.0249 - val_mae: 0.1365
# Epoch 240/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0678 - val_loss: 0.0249 - val_mae: 0.1360
# Epoch 241/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0665 - val_loss: 0.0249 - val_mae: 0.1357
# Epoch 242/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0660 - val_loss: 0.0249 - val_mae: 0.1358
# Epoch 243/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0663 - val_loss: 0.0249 - val_mae: 0.1358
# Epoch 244/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0672 - val_loss: 0.0249 - val_mae: 0.1360
# Epoch 245/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0668 - val_loss: 0.0250 - val_mae: 0.1356
# Epoch 246/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0660 - val_loss: 0.0249 - val_mae: 0.1365
# Epoch 247/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0040 - mae: 0.0677 - val_loss: 0.0248 - val_mae: 0.1349
# Epoch 248/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - mae: 0.0671 - val_loss: 0.0248 - val_mae: 0.1357
# Epoch 249/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0663 - val_loss: 0.0249 - val_mae: 0.1351
# Epoch 250/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0247 - val_mae: 0.1357
# Epoch 251/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0671 - val_loss: 0.0247 - val_mae: 0.1352
# Epoch 252/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0675 - val_loss: 0.0249 - val_mae: 0.1351
# Epoch 253/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0247 - val_mae: 0.1350
# Epoch 254/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0677 - val_loss: 0.0247 - val_mae: 0.1361
# Epoch 255/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0666 - val_loss: 0.0247 - val_mae: 0.1346
# Epoch 256/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0246 - val_mae: 0.1344
# Epoch 257/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - mae: 0.0689 - val_loss: 0.0246 - val_mae: 0.1355
# Epoch 258/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - mae: 0.0667 - val_loss: 0.0247 - val_mae: 0.1349
# Epoch 259/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - mae: 0.0674 - val_loss: 0.0247 - val_mae: 0.1347
# Epoch 260/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042 - mae: 0.0699 - val_loss: 0.0247 - val_mae: 0.1371
# Epoch 261/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0672 - val_loss: 0.0249 - val_mae: 0.1368
# Epoch 262/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - mae: 0.0679 - val_loss: 0.0246 - val_mae: 0.1345
# Epoch 263/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0659 - val_loss: 0.0245 - val_mae: 0.1354
# Epoch 264/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0675 - val_loss: 0.0245 - val_mae: 0.1352
# Epoch 265/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - mae: 0.0665 - val_loss: 0.0247 - val_mae: 0.1352
# Epoch 266/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - mae: 0.0671 - val_loss: 0.0245 - val_mae: 0.1347
# Epoch 267/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0683 - val_loss: 0.0245 - val_mae: 0.1366
# Epoch 268/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041 - mae: 0.0699 - val_loss: 0.0248 - val_mae: 0.1359
# Epoch 269/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0674 - val_loss: 0.0244 - val_mae: 0.1351
# Epoch 270/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - mae: 0.0681 - val_loss: 0.0245 - val_mae: 0.1347
# Epoch 271/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - mae: 0.0683 - val_loss: 0.0244 - val_mae: 0.1348
# Epoch 272/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0661 - val_loss: 0.0246 - val_mae: 0.1347
# Epoch 273/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0672 - val_loss: 0.0244 - val_mae: 0.1346
# Epoch 274/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0685 - val_loss: 0.0245 - val_mae: 0.1373
# Epoch 275/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0687 - val_loss: 0.0246 - val_mae: 0.1352
# Epoch 276/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0667 - val_loss: 0.0244 - val_mae: 0.1343
# Epoch 277/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0675 - val_loss: 0.0244 - val_mae: 0.1349
# Epoch 278/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0038 - mae: 0.0663 - val_loss: 0.0245 - val_mae: 0.1342
# Epoch 279/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0039 - mae: 0.0660 - val_loss: 0.0245 - val_mae: 0.1346
# Epoch 280/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0658 - val_loss: 0.0243 - val_mae: 0.1346
# Epoch 281/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0243 - val_mae: 0.1338
# Epoch 282/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - mae: 0.0663 - val_loss: 0.0243 - val_mae: 0.1338
# Epoch 283/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0656 - val_loss: 0.0242 - val_mae: 0.1340
# Epoch 284/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0674 - val_loss: 0.0243 - val_mae: 0.1336
# Epoch 285/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0660 - val_loss: 0.0243 - val_mae: 0.1336
# Epoch 286/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0244 - val_mae: 0.1342
# Epoch 287/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0668 - val_loss: 0.0242 - val_mae: 0.1335
# Epoch 288/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0668 - val_loss: 0.0243 - val_mae: 0.1339
# Epoch 289/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0665 - val_loss: 0.0241 - val_mae: 0.1336
# Epoch 290/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0241 - val_mae: 0.1333
# Epoch 291/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0672 - val_loss: 0.0241 - val_mae: 0.1333
# Epoch 292/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038 - mae: 0.0659 - val_loss: 0.0241 - val_mae: 0.1331
# Epoch 293/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0660 - val_loss: 0.0241 - val_mae: 0.1331
# Epoch 294/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0666 - val_loss: 0.0241 - val_mae: 0.1330
# Epoch 295/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0654 - val_loss: 0.0243 - val_mae: 0.1337
# Epoch 296/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0241 - val_mae: 0.1326
# Epoch 297/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - mae: 0.0672 - val_loss: 0.0241 - val_mae: 0.1339
# Epoch 298/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0038 - mae: 0.0677 - val_loss: 0.0242 - val_mae: 0.1333
# Epoch 299/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0243 - val_mae: 0.1341
# Epoch 300/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0668 - val_loss: 0.0241 - val_mae: 0.1322
# Epoch 301/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - mae: 0.0659 - val_loss: 0.0240 - val_mae: 0.1322
# Epoch 302/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0038 - mae: 0.0667 - val_loss: 0.0240 - val_mae: 0.1321
# Epoch 303/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0240 - val_mae: 0.1320
# Epoch 304/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0667 - val_loss: 0.0240 - val_mae: 0.1319
# Epoch 305/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0042 - mae: 0.0696 - val_loss: 0.0242 - val_mae: 0.1331
# Epoch 306/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0240 - val_mae: 0.1326
# Epoch 307/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0667 - val_loss: 0.0241 - val_mae: 0.1324
# Epoch 308/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0662 - val_loss: 0.0241 - val_mae: 0.1327
# Epoch 309/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0658 - val_loss: 0.0240 - val_mae: 0.1318
# Epoch 310/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0660 - val_loss: 0.0241 - val_mae: 0.1329
# Epoch 311/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0659 - val_loss: 0.0240 - val_mae: 0.1320
# Epoch 312/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0661 - val_loss: 0.0240 - val_mae: 0.1320
# Epoch 313/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0038 - mae: 0.0664 - val_loss: 0.0239 - val_mae: 0.1317
# Epoch 314/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0039 - mae: 0.0665 - val_loss: 0.0240 - val_mae: 0.1319
# Epoch 315/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0656 - val_loss: 0.0239 - val_mae: 0.1315
# Epoch 316/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0671 - val_loss: 0.0239 - val_mae: 0.1317
# Epoch 317/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0667 - val_loss: 0.0241 - val_mae: 0.1332
# Epoch 318/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0658 - val_loss: 0.0238 - val_mae: 0.1312
# Epoch 319/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - mae: 0.0660 - val_loss: 0.0239 - val_mae: 0.1316
# Epoch 320/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0663 - val_loss: 0.0238 - val_mae: 0.1314
# Epoch 321/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0669 - val_loss: 0.0238 - val_mae: 0.1314
# Epoch 322/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0659 - val_loss: 0.0240 - val_mae: 0.1328
# Epoch 323/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0238 - val_mae: 0.1311
# Epoch 324/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0040 - mae: 0.0689 - val_loss: 0.0237 - val_mae: 0.1314
# Epoch 325/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0037 - mae: 0.0647 - val_loss: 0.0241 - val_mae: 0.1338
# Epoch 326/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0040 - mae: 0.0675 - val_loss: 0.0238 - val_mae: 0.1318
# Epoch 327/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0238 - val_mae: 0.1319
# Epoch 328/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - mae: 0.0689 - val_loss: 0.0239 - val_mae: 0.1324
# Epoch 329/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0039 - mae: 0.0668 - val_loss: 0.0237 - val_mae: 0.1313
# Epoch 330/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0666 - val_loss: 0.0237 - val_mae: 0.1312
# Epoch 331/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0238 - val_mae: 0.1314
# Epoch 332/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - mae: 0.0658 - val_loss: 0.0239 - val_mae: 0.1322
# Epoch 333/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0664 - val_loss: 0.0237 - val_mae: 0.1318
# Epoch 334/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - mae: 0.0679 - val_loss: 0.0238 - val_mae: 0.1317
# Epoch 335/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0660 - val_loss: 0.0238 - val_mae: 0.1308
# Epoch 336/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0239 - val_mae: 0.1317
# Epoch 337/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0038 - mae: 0.0656 - val_loss: 0.0238 - val_mae: 0.1310
# Epoch 338/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038 - mae: 0.0668 - val_loss: 0.0237 - val_mae: 0.1309
# Epoch 339/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038 - mae: 0.0666 - val_loss: 0.0238 - val_mae: 0.1313
# Epoch 340/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - mae: 0.0663 - val_loss: 0.0239 - val_mae: 0.1319
# Epoch 341/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0663 - val_loss: 0.0237 - val_mae: 0.1308
# Epoch 342/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0663 - val_loss: 0.0238 - val_mae: 0.1314
# Epoch 343/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - mae: 0.0687 - val_loss: 0.0238 - val_mae: 0.1315
# Epoch 344/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0653 - val_loss: 0.0237 - val_mae: 0.1306
# Epoch 345/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - mae: 0.0676 - val_loss: 0.0239 - val_mae: 0.1317
# Epoch 346/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0664 - val_loss: 0.0237 - val_mae: 0.1306
# Epoch 347/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0239 - val_mae: 0.1321
# Epoch 348/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0038 - mae: 0.0654 - val_loss: 0.0237 - val_mae: 0.1305
# Epoch 349/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0040 - mae: 0.0684 - val_loss: 0.0236 - val_mae: 0.1307
# Epoch 350/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0675 - val_loss: 0.0241 - val_mae: 0.1336
# Epoch 351/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0663 - val_loss: 0.0236 - val_mae: 0.1307
# Epoch 352/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0238 - val_mae: 0.1319
# Epoch 353/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0236 - val_mae: 0.1307
# Epoch 354/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0663 - val_loss: 0.0237 - val_mae: 0.1304
# Epoch 355/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0238 - val_mae: 0.1319
# Epoch 356/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0668 - val_loss: 0.0238 - val_mae: 0.1316
# Epoch 357/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038 - mae: 0.0651 - val_loss: 0.0236 - val_mae: 0.1305
# Epoch 358/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0236 - val_mae: 0.1306
# Epoch 359/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0237 - val_mae: 0.1310
# Epoch 360/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0038 - mae: 0.0659 - val_loss: 0.0236 - val_mae: 0.1303
# Epoch 361/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0236 - val_mae: 0.1303
# Epoch 362/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0236 - val_mae: 0.1308
# Epoch 363/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - mae: 0.0666 - val_loss: 0.0237 - val_mae: 0.1314
# Epoch 364/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0040 - mae: 0.0668 - val_loss: 0.0238 - val_mae: 0.1318
# Epoch 365/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0682 - val_loss: 0.0235 - val_mae: 0.1299
# Epoch 366/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0677 - val_loss: 0.0239 - val_mae: 0.1327
# Epoch 367/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0235 - val_mae: 0.1299
# Epoch 368/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0675 - val_loss: 0.0237 - val_mae: 0.1318
# Epoch 369/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0235 - val_mae: 0.1301
# Epoch 370/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0038 - mae: 0.0660 - val_loss: 0.0235 - val_mae: 0.1300
# Epoch 371/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0236 - val_mae: 0.1312
# Epoch 372/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0650 - val_loss: 0.0235 - val_mae: 0.1301
# Epoch 373/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0235 - val_mae: 0.1302
# Epoch 374/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0235 - val_mae: 0.1299
# Epoch 375/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0667 - val_loss: 0.0238 - val_mae: 0.1322
# Epoch 376/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0653 - val_loss: 0.0235 - val_mae: 0.1298
# Epoch 377/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0683 - val_loss: 0.0235 - val_mae: 0.1297
# Epoch 378/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0037 - mae: 0.0652 - val_loss: 0.0238 - val_mae: 0.1327
# Epoch 379/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041 - mae: 0.0668 - val_loss: 0.0236 - val_mae: 0.1303
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0235 - val_mae: 0.1298
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0236 - val_mae: 0.1311
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0660 - val_loss: 0.0235 - val_mae: 0.1298
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0235 - val_mae: 0.1304
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0038 - mae: 0.0653 - val_loss: 0.0237 - val_mae: 0.1315
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - mae: 0.0691 - val_loss: 0.0234 - val_mae: 0.1298
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - mae: 0.0648 - val_loss: 0.0240 - val_mae: 0.1337
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0655 - val_loss: 0.0235 - val_mae: 0.1304
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0670 - val_loss: 0.0234 - val_mae: 0.1299
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - mae: 0.0648 - val_loss: 0.0238 - val_mae: 0.1325
# Epoch 390/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0656 - val_loss: 0.0235 - val_mae: 0.1298
# Epoch 391/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0037 - mae: 0.0654 - val_loss: 0.0235 - val_mae: 0.1301
# Epoch 392/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0236 - val_mae: 0.1308
# Epoch 393/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - mae: 0.0649 - val_loss: 0.0234 - val_mae: 0.1295
# Epoch 394/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0668 - val_loss: 0.0234 - val_mae: 0.1294
# Epoch 395/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0236 - val_mae: 0.1311
# Epoch 396/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0656 - val_loss: 0.0235 - val_mae: 0.1300
# Epoch 397/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - mae: 0.0654 - val_loss: 0.0234 - val_mae: 0.1296
# Epoch 398/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0037 - mae: 0.0653 - val_loss: 0.0235 - val_mae: 0.1298
# Epoch 399/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - mae: 0.0647 - val_loss: 0.0235 - val_mae: 0.1306
# Epoch 400/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0673 - val_loss: 0.0233 - val_mae: 0.1288
# Epoch 401/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0237 - val_mae: 0.1323
# Epoch 402/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0667 - val_loss: 0.0233 - val_mae: 0.1290
# Epoch 403/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0236 - val_mae: 0.1311
# Epoch 404/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0234 - val_mae: 0.1294
# Epoch 405/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0234 - val_mae: 0.1299
# Epoch 406/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0646 - val_loss: 0.0238 - val_mae: 0.1329
# Epoch 407/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0672 - val_loss: 0.0233 - val_mae: 0.1286
# Epoch 408/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0665 - val_loss: 0.0234 - val_mae: 0.1303
# Epoch 409/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0665 - val_loss: 0.0233 - val_mae: 0.1292
# Epoch 410/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0042 - mae: 0.0684 - val_loss: 0.0237 - val_mae: 0.1326
# Epoch 411/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0664 - val_loss: 0.0232 - val_mae: 0.1291
# Epoch 412/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0039 - mae: 0.0676 - val_loss: 0.0234 - val_mae: 0.1304
# Epoch 413/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0037 - mae: 0.0650 - val_loss: 0.0236 - val_mae: 0.1316
# Epoch 414/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0651 - val_loss: 0.0233 - val_mae: 0.1294
# Epoch 415/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0654 - val_loss: 0.0232 - val_mae: 0.1288
# Epoch 416/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0664 - val_loss: 0.0233 - val_mae: 0.1293
# Epoch 417/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0656 - val_loss: 0.0237 - val_mae: 0.1328
# Epoch 418/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0660 - val_loss: 0.0233 - val_mae: 0.1291
# Epoch 419/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0668 - val_loss: 0.0233 - val_mae: 0.1294
# Epoch 420/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - mae: 0.0645 - val_loss: 0.0235 - val_mae: 0.1315
# Epoch 421/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0658 - val_loss: 0.0233 - val_mae: 0.1298
# Epoch 422/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0039 - mae: 0.0666 - val_loss: 0.0231 - val_mae: 0.1295
# Epoch 423/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0664 - val_loss: 0.0237 - val_mae: 0.1327
# Epoch 424/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0653 - val_loss: 0.0232 - val_mae: 0.1292
# Epoch 425/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038 - mae: 0.0669 - val_loss: 0.0233 - val_mae: 0.1300
# Epoch 426/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - mae: 0.0657 - val_loss: 0.0238 - val_mae: 0.1334
# Epoch 427/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - mae: 0.0649 - val_loss: 0.0231 - val_mae: 0.1294
# Epoch 428/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0685 - val_loss: 0.0231 - val_mae: 0.1293
# Epoch 429/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0237 - val_mae: 0.1328
# Epoch 430/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0039 - mae: 0.0667 - val_loss: 0.0232 - val_mae: 0.1294
# Epoch 431/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0663 - val_loss: 0.0231 - val_mae: 0.1293
# Epoch 432/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0038 - mae: 0.0661 - val_loss: 0.0231 - val_mae: 0.1293
# Epoch 433/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0038 - mae: 0.0653 - val_loss: 0.0235 - val_mae: 0.1316
# Epoch 434/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0038 - mae: 0.0649 - val_loss: 0.0232 - val_mae: 0.1297
# Epoch 435/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0667 - val_loss: 0.0231 - val_mae: 0.1291
# Epoch 436/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038 - mae: 0.0658 - val_loss: 0.0233 - val_mae: 0.1297
# Epoch 437/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0652 - val_loss: 0.0234 - val_mae: 0.1304
# Epoch 438/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0660 - val_loss: 0.0231 - val_mae: 0.1287
# Epoch 439/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0666 - val_loss: 0.0235 - val_mae: 0.1314
# Epoch 440/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0656 - val_loss: 0.0231 - val_mae: 0.1286
# Epoch 441/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0233 - val_mae: 0.1295
# Epoch 442/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0039 - mae: 0.0660 - val_loss: 0.0233 - val_mae: 0.1296
# Epoch 443/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0038 - mae: 0.0661 - val_loss: 0.0231 - val_mae: 0.1285
# Epoch 444/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0659 - val_loss: 0.0235 - val_mae: 0.1312
# Epoch 445/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038 - mae: 0.0655 - val_loss: 0.0231 - val_mae: 0.1284
# Epoch 446/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0037 - mae: 0.0658 - val_loss: 0.0233 - val_mae: 0.1302
# Epoch 447/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0037 - mae: 0.0648 - val_loss: 0.0233 - val_mae: 0.1305
# Epoch 448/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0037 - mae: 0.0645 - val_loss: 0.0230 - val_mae: 0.1283
# Epoch 449/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mae: 0.0693 - val_loss: 0.0230 - val_mae: 0.1284
# Epoch 450/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0670 - val_loss: 0.0236 - val_mae: 0.1325
# Epoch 451/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0038 - mae: 0.0651 - val_loss: 0.0232 - val_mae: 0.1295
# Epoch 452/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0039 - mae: 0.0680 - val_loss: 0.0230 - val_mae: 0.1284
# Epoch 453/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0037 - mae: 0.0654 - val_loss: 0.0238 - val_mae: 0.1337
# Epoch 454/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0231 - val_mae: 0.1288
# Epoch 455/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0037 - mae: 0.0656 - val_loss: 0.0233 - val_mae: 0.1299
# Epoch 456/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0037 - mae: 0.0649 - val_loss: 0.0231 - val_mae: 0.1292
# Epoch 457/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0038 - mae: 0.0662 - val_loss: 0.0231 - val_mae: 0.1287
# Epoch 458/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0663 - val_loss: 0.0234 - val_mae: 0.1310
# Epoch 459/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037 - mae: 0.0649 - val_loss: 0.0229 - val_mae: 0.1284
# Epoch 460/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0674 - val_loss: 0.0232 - val_mae: 0.1299
# Epoch 461/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - mae: 0.0645 - val_loss: 0.0235 - val_mae: 0.1318
# Epoch 462/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0037 - mae: 0.0642 - val_loss: 0.0230 - val_mae: 0.1282
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0038 - mae: 0.0667 - val_loss: 0.0231 - val_mae: 0.1285
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - mae: 0.0643 - val_loss: 0.0236 - val_mae: 0.1320
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039 - mae: 0.0657 - val_loss: 0.0232 - val_mae: 0.1292
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0040 - mae: 0.0699 - val_loss: 0.0229 - val_mae: 0.1288
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0041 - mae: 0.0678 - val_loss: 0.0243 - val_mae: 0.1374
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0230 - val_mae: 0.1284
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0038 - mae: 0.0667 - val_loss: 0.0231 - val_mae: 0.1286
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0667 - val_loss: 0.0237 - val_mae: 0.1324
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0229 - val_mae: 0.1290
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - mae: 0.0684 - val_loss: 0.0235 - val_mae: 0.1315
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0039 - mae: 0.0656 - val_loss: 0.0233 - val_mae: 0.1303
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0036 - mae: 0.0640 - val_loss: 0.0229 - val_mae: 0.1286
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0039 - mae: 0.0680 - val_loss: 0.0230 - val_mae: 0.1283
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0652 - val_loss: 0.0234 - val_mae: 0.1306
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0229 - val_mae: 0.1284
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - mae: 0.0655 - val_loss: 0.0236 - val_mae: 0.1322
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0039 - mae: 0.0650 - val_loss: 0.0233 - val_mae: 0.1305
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0230 - val_mae: 0.1280
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0041 - mae: 0.0679 - val_loss: 0.0235 - val_mae: 0.1314
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0037 - mae: 0.0644 - val_loss: 0.0229 - val_mae: 0.1281
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - mae: 0.0661 - val_loss: 0.0234 - val_mae: 0.1310
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0039 - mae: 0.0650 - val_loss: 0.0234 - val_mae: 0.1309
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0040 - mae: 0.0680 - val_loss: 0.0229 - val_mae: 0.1282
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0037 - mae: 0.0646 - val_loss: 0.0235 - val_mae: 0.1314
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041 - mae: 0.0678 - val_loss: 0.0234 - val_mae: 0.1309
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0648 - val_loss: 0.0228 - val_mae: 0.1286
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0037 - mae: 0.0671 - val_loss: 0.0236 - val_mae: 0.1321
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0040 - mae: 0.0675 - val_loss: 0.0237 - val_mae: 0.1337
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0664 - val_loss: 0.0228 - val_mae: 0.1282
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0681 - val_loss: 0.0234 - val_mae: 0.1313
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0037 - mae: 0.0646 - val_loss: 0.0230 - val_mae: 0.1287
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0038 - mae: 0.0663 - val_loss: 0.0229 - val_mae: 0.1283
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - mae: 0.0651 - val_loss: 0.0233 - val_mae: 0.1306
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037 - mae: 0.0646 - val_loss: 0.0230 - val_mae: 0.1289
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0037 - mae: 0.0651 - val_loss: 0.0230 - val_mae: 0.1289
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0037 - mae: 0.0650 - val_loss: 0.0228 - val_mae: 0.1282
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0037 - mae: 0.0655 - val_loss: 0.0228 - val_mae: 0.1282
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - mae: 0.0650 - val_loss: 0.0231 - val_mae: 0.1295
# Valid MAE sin normalizar (LSTM-32): 0.1280256062746048
# Valid MAE (LSTM-32): 362,770 votos/5min
